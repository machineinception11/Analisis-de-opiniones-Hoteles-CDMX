# %% [markdown]
# # Extracción de Opiniones Hotel 3.	Zocalo Centarl Hotel ($1889)

# %%
# Importamos librerias
from time import sleep
import pandas as pd
import random
from scrapy.item import Item
from scrapy.item import Field
from scrapy.spiders import CrawlSpider, Rule
from scrapy.loader import ItemLoader
from scrapy.linkextractors import LinkExtractor
from scrapy.selector import Selector
from scrapy.crawler import CrawlerProcess

# %%
class Opiniones(Item):
    nombre = Field()
    opinion = Field()
    calificacion = Field()
    fecha = Field()
    
class Hotel(CrawlSpider):
    # Definimos el nombre del spider
    name = "MumediDesignHotel"
    
    # Definimos la seguridad para no sér detectados
    custom_settings = ({
        "USER_AGENT": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.77 Safari/537.36"
    })
    
    # Tiempo de descarga
    download_delay = 1
    
    # ¿De dónde extraerémos los datos?
    start_urls = ["https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html"]
    
    # ¿Qué páginas están permitidas?
    allowed_domain = ["tripadvisor.com.mx"]
    
    # Definimos las reglas
    # Scraping horizontal
    rules = (
        Rule(
            LinkExtractor(
                allow = r'-or\d+'
            ), follow = True, callback = 'parse_opiniones'
        ),
    )
    
    # Definimos la función para el parseador
    def parse_opiniones(self, response):
        sel = Selector(response)
        # opiniones = sel.xpath('//div[@data-test-target="reviews-tab"]/div[@data-test-target = HR_CC_CARD]')
        opiniones = sel.xpath('//div[@id = "taplc_resp_hr_ad_wrapper_lower_block_0"]/div/div/div/div/div/div[3]/div[@data-test-target="HR_CC_CARD"]')
        
        for opinion in opiniones:
            item = ItemLoader(Opiniones(), opinion)
            item.add_xpath('nombre', './/a[@class = "ui_header_link _1r_My98y"]/text()')
            item.add_xpath('opinion', './/q[@class = "IRsGHoPm"]/span/text()') 
            item.add_xpath('calificacion', './/div[@data-test-target = "review-rating"]/span[contains(@class, "ui_bubble_rating")]/@class')
            item.add_xpath('fecha', './/span[@class = "_34Xs-BQm"]/text()') 
            
            yield item.load_item()

# %%
process = CrawlerProcess({
    "FEED_FORMAT": "csv",
    "FEED_URI": "ZocaloCentralHotel_Trip.csv"
})

process.crawl(Hotel)
process.start()
# Out:
# 2021-04-01 21:14:22 [scrapy.utils.log] INFO: Scrapy 2.4.1 started (bot: scrapybot)
# 2021-04-01 21:14:22 [scrapy.utils.log] INFO: Versions: lxml 4.6.1.0, libxml2 2.9.10, cssselect 1.1.0, parsel 1.5.2, w3lib 1.21.0, Twisted 21.2.0, Python 3.7.7 (default, May  6 2020, 11:45:54) [MSC v.1916 64 bit (AMD64)], pyOpenSSL 19.1.0 (OpenSSL 1.1.1k  25 Mar 2021), cryptography 3.2.1, Platform Windows-10-10.0.19041-SP0
# 2021-04-01 21:14:22 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2021-04-01 21:14:22 [scrapy.crawler] INFO: Overridden settings:
# {'USER_AGENT': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 '
#                '(KHTML, like Gecko) Chrome/70.0.3538.77 Safari/537.36'}
# 2021-04-01 21:14:22 [scrapy.extensions.telnet] INFO: Telnet Password: ebff658aefa8ea4e
# 2021-04-01 21:14:22 [py.warnings] WARNING: D:\Anaconda\lib\site-packages\scrapy\extensions\feedexport.py:247: ScrapyDeprecationWarning: The `FEED_URI` and `FEED_FORMAT` settings have been deprecated in favor of the `FEEDS` setting. Please see the `FEEDS` setting docs for more details
#   exporter = cls(crawler)
#
# 2021-04-01 21:14:22 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2021-04-01 21:14:22 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2021-04-01 21:14:22 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2021-04-01 21:14:22 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2021-04-01 21:14:22 [scrapy.core.engine] INFO: Spider opened
# 2021-04-01 21:14:22 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2021-04-01 21:14:22 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2021-04-01 21:14:25 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html> (referer: None)
# 2021-04-01 21:14:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or5-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html> (referer: https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html)
# 2021-04-01 21:14:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or5-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_50'],
#  'fecha': [' marzo de 2020'],
#  'nombre': ['Carlos'],
#  'opinion': ['Excelente ubicación. Personal muy servicial y atento. Nos '
#              'encantó. Planeamos regresar. Su restaurante de comida '
#              'contemporánea mexicana es excelente y hornean un pan delicioso, '
#              'que también pueden comprar para llevar. Dan recorridos por la '
#              'ciudad para aquellas personas que no la conocen. Es una buena '
#              'opción sin costo extra. Cuentan con servicio de planificación de '
#              'actividades.']}
# 2021-04-01 21:14:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or5-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_50'],
#  'fecha': [' marzo de 2020'],
#  'nombre': ['Antonio H'],
#  'opinion': ['Estuvimos muy contentos, el hotel se ve como nuevo, fueron muy '
#              'amables en la recepcion, el restaurante esta increíble y la '
#              'comida deliciosa, en el buffett gratis del desayuno Brandon y '
#              'Daniel fueron particularmente amables, con pandulce y tortillas '
#              'recien hechas de cortesía. Excelente hotel muy ubicado, directo '
#              'en el Zócalo (con estacionamiento propio sin costo).']}
# 2021-04-01 21:14:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or5-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_50'],
#  'fecha': [' febrero de 2020'],
#  'nombre': ['NicolaMarzotto'],
#  'opinion': ['Meseros muy gentiles y amables. Perfecto  equilibrio '
#              'claridad/precio. Comida sabrosa y vista preciosa del zócalo. Una '
#              'experiencia que todos tienen que hacer si visitan la ciudad de '
#              'México. Muy recomendable. ']}
# 2021-04-01 21:14:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or5-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_50'],
#  'fecha': [' febrero de 2020'],
#  'nombre': ['Paula U'],
#  'opinion': ['Nos quedamos en este hotel la semana pasada, desgraciadamente '
#              'sólo por dos noches, ya que nos hubiera encantado hacerlo por '
#              'más tiempo. Lo que nos encantó: -la ubicación; -el servicio (los '
#              'recepcionistas, el personal del restaurante y de la cafetería, '
#              'así como concierge y botones); -las botellas de agua en cada '
#              'piso (súper útiles en la Ciudad de México); -la habitación '
#              '(limpia y agradable); -los detalles que nos dejaban por la '
#              'noche; -el pan que ofrecen en el desayuno estaba espectacular; '
#              '-el restaurante y las vistas. Lo que se podría mejorar: -la '
#              'oferta de desayuno es un poquito limitada, lo que tienen está '
#              'muy bien, pero podrían tener un poco más. En cualquier caso '
#              'pienso quedarme en este hotel cada vez que vaya a México.']}
# 2021-04-01 21:14:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or5-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_50'],
#  'fecha': [' abril de 2019'],
#  'nombre': ['Liebre 3015'],
#  'opinion': ['Siempre que voy a CDMX solo en este hotel me hospedo. Es '
#              'excelente, habitaciones amplias e impecables, un restaurante de '
#              'primer nivel y con la mejor vista de la ciudad, la atención '
#              'inmejorable, en el corazón del Centro Histórico, con detalles '
#              'insuperables como el agua y las manzanas. Y frente al Zócalo, La '
#              'Catedral y el Palacio Nacional; no se puede pedir más es el '
#              'mejor.']}
# 2021-04-01 21:14:26 [scrapy.dupefilters] DEBUG: Filtered duplicate request: <GET https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or5-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html> - no more duplicates will be shown (see DUPEFILTER_DEBUG to show all duplicates)
# 2021-04-01 21:14:27 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or1210-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html> (referer: https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html)
# 2021-04-01 21:14:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or1210-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_40'],
#  'nombre': ['Mato'],
#  'opinion': ['  El Holiday Inn ciudad de México justo en el centro del Zócalo '
#              'es un encantador, limpio eficiente hotel. Las habitaciones son '
#              'espaciosas y el personal está dispuesto a ayudar. El acceso '
#              'gratuito a Internet en el vestíbulo es realmente bonito. Las '
#              'vistas desde la terraza restaurante categoría es maravilloso.  ']}
# 2021-04-01 21:14:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or1210-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_40'],
#  'nombre': ['DocDick_47'],
#  'opinion': ['La ubicación de este Holiday Inn - Zócalo es ideal para visitar '
#              'varios días de actividades a pie. Las habitaciones son bonitas y '
#              'bien ventilada, el personal muy servicial. Disfruté de la '
#              'internet gratis. ¡Seguro los taxis son rápidamente médicos para '
#              'llevar a los excelentes museos y parques en otras partes de la '
#              'ciudad.']}
# 2021-04-01 21:14:29 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or25-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html> (referer: https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html)
# 2021-04-01 21:14:29 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or25-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_50'],
#  'fecha': [' septiembre de 2019'],
#  'nombre': ['Elias Noriega'],
#  'opinion': ['La vista al Zócalo es increíble y visitarlo en septiembre justo '
#              'en la fecha del grito de la independencia (15 de septiembre) es '
#              'lo mejor, su ubicación es inmejorable, la atención del personal '
#              'y las habitaciones muy lindas ']}
# 2021-04-01 21:14:29 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or25-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_50'],
#  'fecha': [' abril de 2019'],
#  'nombre': ['Luis C'],
#  'opinion': ['El Hotel tiene una excelente ubicación; sin mencionar de la '
#              'vista increíble de su Restaurante donde te sirven el desayuno y '
#              'puedes disfrutar de una cocina de primera a la hora del almuerzo '
#              'y la cena!!  La atención del personal es excelente, son muy '
#              'amables y todo el tiempo están muy atentos a cualquier '
#              'requerimiento o necesidad!!  Lo recomiendo si quieres disfrutar '
#              'de la vida del pleno centro de la Ciudad de México!!!']}
# 2021-04-01 21:14:29 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or25-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_50'],
#  'fecha': [' julio de 2019'],
#  'nombre': ['Milagros QD'],
#  'opinion': ['Éramos 4 personas en una habitación realmente cómoda para el '
#              'número. Realmente nos vamos con la mejor de las experiencias '
#              'gracias a ellos que nos hacen sentir como en casa. El personal '
#              'es súper amable, tendría que mencionarlos a todos. El desayuno '
#              'es realmente acogedor y no hay forma de no disfrutar de esa '
#              'hermosa vista que tienen, un privilegio. Además, la cafetería es '
#              'muy completa y bien diversificada considerando que venimos de '
#              'todas partes del mundo y de distintas edades. Me encantó, una '
#              'atención de primera.']}
# 2021-04-01 21:14:29 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or25-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_50'],
#  'fecha': [' junio de 2019'],
#  'nombre': ['Cristina M'],
#  'opinion': ['Sin duda el mejor hotel en el zócalo de la Ciudad de México, '
#              'hermoso, elegante, el restaurante de arriba delicioso además de '
#              'tener una vista espectacular. Realmente el precio del hotel vale '
#              'cada centavo, muy recomendable! ']}
# 2021-04-01 21:14:29 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or25-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_50'],
#  'fecha': [' junio de 2019'],
#  'nombre': ['LAO07'],
#  'opinion': ['La ubicación es extraordinaria, en la Plaza de la Constitución '
#              '(el Zócalo) justo al lado de la catedral.  La habitación y el '
#              'baño de la habitación que reservamos eran pequeños aunque '
#              'bastante completos.  El desayuno se toma en la terraza del hotel '
#              'con unas vistas magníficas a la catedral, al palacio nacional y '
#              'al conjunto de la plaza del Zócalo.  Ofrece parking gratis.  '
#              'Aunque no lo probamos, nos dijeron que las consumiciones en la '
#              'cafetería eran gratis salvo las bebidas alcohólicas.']}
# 2021-04-01 21:14:30 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or20-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html> (referer: https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html)
# 2021-04-01 21:14:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or20-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_50'],
#  'fecha': [' septiembre de 2019'],
#  'nombre': ['jocorqui'],
#  'opinion': ['Un lugar muy agradable, con una vista muy espectacular porque '
#              'tiene a la Catedral enfrente,  viendo su perfil hermoso. Y una '
#              'vista panorámica de la plancha del Zócalo capitalino, '
#              'disfrutando para empezar de un rico café y pan dulce; luego unos '
#              'chilaquiles con carne asada deliciosos. Muy recomendable hacer '
#              'su reservación con anticipación porque es un lugar muy '
#              'visitado.']}
# 2021-04-01 21:14:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or20-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_50'],
#  'fecha': [' octubre de 2019'],
#  'nombre': ['HectorOaks'],
#  'opinion': ['Hola Viajeros!, como siempre sere breve a continuacion les hago '
#              'saber mis perspectivas de nuestro hospedaje: 1. Desayuno '
#              'incluido, buen sabor...recomiendo pedir a la carta; ya que el '
#              'alimento en buffet esta un poco frio, la cena para mi gusto un '
#              'tanto cara, aun que se vee que es sabrosa,  2. Les recomiendo '
#              'visitar a un costado de recepcion la cafeteria la cual tiene '
#              'algunos snacks desde panninis, papitas, frapes, pastelitos, '
#              'etc....muy amable la chica que nos atendio 3.la habitacion a mi '
#              'gusto un poco chica pero super bien amueblada, el colchon era '
#              'kingsize, a mi ver un poco gastado el colchon pero en general '
#              'bien, buena limpieza 4. Los chicos/ chicas de recepcion bien '
#              'amables 5. Los precios de las habitaciones son un tanto '
#              'razonables ( aprox 3800 x noche ) tomando en cuenta que',
#              '…']}
# 2021-04-01 21:14:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or20-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_40'],
#  'fecha': [' septiembre de 2019'],
#  'nombre': ['Mauricio C'],
#  'opinion': ['Viaje con mi familia a Ciudad de México una visita rápida y de '
#              'turismo donde nos quedamos una noche en este hotel y separamos '
#              'dos habitaciones, al llegar al Check in nos dieron dos '
#              'habitaciones en pisos diferentes les pido si pueden estar en un '
#              'solo piso indican que no tienen disponibilidad, cuando llegamos '
#              'a las habitaciones tocan la puerta para preguntar cómo estaba '
#              'todo, cabe mencionar que cuando fuimos a las dos habitaciones '
#              'las llaves no abrían la puerta y pudimos entrar ya que '
#              'Housekeeping nos abrió la puerta muy amablemente, cuando le '
#              'informamos que no funcionan las llaves mandar a cambiarlas pero '
#              'nos indican que si pudieron encontrar habitaciones por los que '
#              'nos emocionamos de poder estar una al lado cuando preguntamos '
#              'nos indican que ya habían ocupado las habitaciones y',
#              '…']}
# 2021-04-01 21:14:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or20-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_50'],
#  'fecha': [' septiembre de 2019'],
#  'nombre': ['margarita'],
#  'opinion': ['Fueron 5 días de un servicio super excelentisimo. Las '
#              'habitaciones muy limpias, Isabel, la chica que nos limpiaba el '
#              'cuarto, super amable y atenta con nosotros, un lugar centrico '
#              'que te puede llevar donde quieras. El restaurante, la mejor '
#              'vista del Zocalo, la atención muy bueno, los chicos super '
#              'amables y atentos y muy educados, los chilaquiles verdes '
#              'deliciosos, en general la comida de primera. Te mantienen '
#              'informado, si necesitas algo, siempre estan atentos contigo, en '
#              'fin, nos vamos muy contenta de México. No solo por el hotel que '
#              'es de primera, sino porque nos llevamos las mejores '
#              'experiencias. Soy campechana y mi marido Joost holandes.']}
# 2021-04-01 21:14:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or20-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_10'],
#  'fecha': [' septiembre de 2019'],
#  'nombre': ['daniela hernandez'],
#  'opinion': ['Tuve una pésima atencion por parte del personal de recepción del '
#              'hotel, ya que me tuvieron esperando 2 horas para entregarme mi '
#              'habitación, llegue al hotel cerca de las 2 pm y el check in era '
#              'a las 3,me comentaron que no estaba aun la habitación pero que a '
#              'las 3 ya estaría lista.Realice esta reservación por callcenter y '
#              'sus beneficios por reservar directo es que podemos hacer checkin '
#              'temprano y el checkout tardío,a todo esto,estoy en espera de mi '
#              'habitación dando las 3 de la tarde cuando ya debería estar lista '
#              'la habitación y pregunto a la chica de recepción y me dice que '
#              'tardaran mas, que hasta las 4 me la iban a entregar, y estamos '
#              'hablando que reserve una habitación suite con vista al zocalo y '
#              'que la habitación ya estaba pagada,y que ni siquiera me '
#              'entregaron mi voucher al',
#              '…']}
# 2021-04-01 21:14:32 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or15-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html> (referer: https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html)
# 2021-04-01 21:14:32 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or15-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_50'],
#  'fecha': [' noviembre de 2019'],
#  'nombre': ['Monse66'],
#  'opinion': ['El hotel esta super bien ubicado, las habitaciones son hermosas, '
#              'el restaurante en el 6° piso tiene una vista impresionante, el '
#              'desayuno es delicioso y el staff es maravilloso!!! Estamos muy '
#              'agradecidos con todos!!! En especial con las chicas del counter, '
#              'son divinas!!!! Seguro volveremos! Felicitaciones!!!!']}
# 2021-04-01 21:14:32 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or15-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_20'],
#  'fecha': [' mayo de 2019'],
#  'nombre': ['MA C'],
#  'opinion': ['El fin de semana tenían buffet. la comida muy mala, sin sabor, '
#              'mucha cantidad pero sin calidad. no vale la pena. Precio x '
#              'calidad cero. La atención es mala. al entrar en el lobby del '
#              'hotel casi no me dejan entrar, mal trato, creo que por '
#              'racismo. ']}
# 2021-04-01 21:14:32 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or15-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_50'],
#  'fecha': [' noviembre de 2018'],
#  'nombre': ['ViajeraMexi-Can77'],
#  'opinion': ['La atenciòn es excelente desde recepcion y bell boys, ayudandome '
#              'en todas mis dudas y acompañandome en todo momento Excelente '
#              'ubicaciòn, ideal para familias, el desayuno muy bueno, en '
#              'conjunto una buena experiencia']}
# 2021-04-01 21:14:32 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or15-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_50'],
#  'fecha': [' julio de 2019'],
#  'nombre': ['Anahí L'],
#  'opinion': ['Estructura edilicia, amenities , ubicación, vistas...Espléndido '
#              '! Competencia profesional. La cocina de su restaurante Balcón '
#              'del zócalo expone la producción continua de alimentos:\xa0'
#              '“impecable”, y el bar ofrece bocados y bebidas incluidas en el '
#              'precio del alojamiento y se convierte en un oasis a la vuelta '
#              'del recorrido diario por la bella Ciudad de México! Muy '
#              'recomendable!\xa0']}
# 2021-04-01 21:14:32 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or15-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_50'],
#  'fecha': [' octubre de 2019'],
#  'nombre': ['Paula Young'],
#  'opinion': ['La experiencia en Zócalo Central fue fabulosa y merece ser '
#              'compartida. Excelente atención. Impecables instalaciones. Buena '
#              'comida. Preocupación por los detalles (gracias Isabel Velázquez, '
#              'hasta nos dejaba tarjetas con el pronóstico del clima para el '
#              'día siguiente) y facilidad en todos los procesos: check in/out, '
#              'consultas, indicaciones. Para nosotros se volvió un hotel para '
#              'ser recomendado siempre y, evidentemente, reserva segura si '
#              'volvemos a Ciudad de México. Felicitaciones. Un hotel dedicado a '
#              'la atención personalizada y cálida.']}
# 2021-04-01 21:14:33 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or10-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html> (referer: https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html)
# 2021-04-01 21:14:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or10-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_40'],
#  'fecha': [' enero de 2020'],
#  'nombre': ['martha18'],
#  'opinion': ['El personal muy amable cuanto limpio excelente servicio, '
#              'solamente una queja... los meseros de la cafeteria los sentimos '
#              'un poco descriminatorios hacia nuestra apariencia   (mexicana '
#              'aunque somos USA citizens), ellos se desviven por atender a los '
#              'de apariencia americana']}
# 2021-04-01 21:14:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or10-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_50'],
#  'fecha': [' enero de 2020'],
#  'nombre': ['Paolavegar'],
#  'opinion': ['El hotel es maravilloso. La ubicación excelente, prácticamente a '
#              'la par del Zócalo, perfecto para moverse a cualquier parte de la '
#              'ciudad. Las habitaciones hermosas y la limpieza exc. El trato '
#              'del personal es espectacular y el hotel cuenta con amenidades '
#              'sumamente buenas como un café 24/7 donde se puede comer gratis '
#              'ensaladas, sándwiches deliciosos, café, bebidas. Siempre hay '
#              'agua y manzanas gratis en las habitaciones. El restaurante es '
#              'delicioso y tiene la mejor vista al centro histórico. '
#              'Recomendado 100% ']}
# 2021-04-01 21:14:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or10-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_10'],
#  'fecha': [' diciembre de 2019'],
#  'nombre': ['Hector Esteban R'],
#  'opinion': ['En el checkout cobran más de lo inicial.ademas no entregan '
#              'factura con el IVA que uno paga. De nada sirve tener un servicio '
#              'aceptable si al momento de facturar todo esta mal. Solo dan '
#              'recibos y nunca una factura.']}
# 2021-04-01 21:14:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or10-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_50'],
#  'fecha': [' diciembre de 2019'],
#  'nombre': ['JMPalacios'],
#  'opinion': ['Estuvimos por segunda vez en Zócalo Central, y de nuevo, '
#              'nuestras expectativas fueron excedidas, desde Las atenciones y '
#              'seguimiento de Eduardo, la gente de recepción, el Café central y '
#              'las personas de la puerta, excelentes! La persona que nos apoyo '
#              'con el equipaje en la salida, amable, y súper servicial. Al '
#              'finalizar, ya para tomar la ruta al aeropuerto, la amabilidad y '
#              'espíritu de servicio de Oswaldo, el piloto del taxi (que por lo '
#              'que sé, también es parte del hotel), realmente bueno. '
#              'Felicitaciones por mantener ese alto nivel de servicio, con '
#              'seguridad volveremos de nuevo!!']}
# 2021-04-01 21:14:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or10-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_40'],
#  'fecha': [' diciembre de 2019'],
#  'nombre': ['Fernando C'],
#  'opinion': ['Bonito lugar para poder visitar. Se rodea de lindos edificios '
#              'antiguos que enriquecen la vista y la visita.  Realizan muchos '
#              'eventos acá lo que dificulta poder apreciar por completo el '
#              'lugar.  Es de fácil acceso y es muy emblemático. ']}
# 2021-04-01 21:14:33 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tripadvisor.com.mx/RegistrationController?flow=sign_up_and_save&returnTo=%2FHotel_Review-g150800-d185401-Reviews-or5-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html&fullscreen=true&flowOrigin=login&hideNavigation=true> (referer: https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or5-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html)
# 2021-04-01 21:14:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or1200-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html> (referer: https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or1210-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html)
# 2021-04-01 21:14:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or1200-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_50'],
#  'nombre': ['rgon'],
#  'opinion': ['Nos alojamos dos noches en este hotel. La ubicación era '
#              'estupenda, ya que es sólo un paseo corto a las atracciones '
#              'principales de la zona del centro de la ciudad. El hotel en sí '
#              'era precioso y estaba impecable. Nuestra habitación era un poco '
#              'pequeña, pero estaba muy bien. El restaurante era bueno, y la '
#              'zona comer fuera era muy agradable durante el día. Por la noche, '
#              'que era un poco demasiado fría a comer fuera. El personal acaba '
#              'de hotel era muy complaciente y servicial. Nos dieron con todo '
#              'tipo de información, de la seguridad de entretenimiento, lo hizo '
#              'todo y de nuestra organización que necesitábamos. El precio era '
#              'muy razonable para la calidad. Lo recomiendo encarecidamente '
#              'este hotel! ']}
# 2021-04-01 21:14:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or1200-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_40'],
#  'fecha': [' mayo de 2006'],
#  'nombre': ['ridgeley'],
#  'opinion': ['Este es mi segunda vez alojarme aquí. Estuve ahí en mayo de '
#              '2005, también, aunque estuvieran remodelando.  El hotel parece '
#              'mucho más agradable después de la remodelación, además, ahora '
#              'tienen internet inalámbrica en la habitación, lo que es muy '
#              'práctico. También tienen un pequeño centro de negocios donde '
#              'puedes usar su conexión a internet de alta velocidad de semi-por '
#              '30 minutos por día, además imprimir si quieres.  La habitación '
#              'estaba limpia, la caja fuerte funcionaba, había agua caliente '
#              'abundante y los baños siempre tiraba. Si tienes una habitación '
#              'en el lado de la calle, y te dan un poco de ruido de la calle, '
#              'pero es tranquilo para las 8:00 o 9:00. El año pasado, en una '
#              'habitación interior, y encontramos el ruido de la gente eco en '
#              'el conducto de ser mucho más molesto.',
#              '…']}
# 2021-04-01 21:14:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or1200-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_40'],
#  'nombre': ['yvr1'],
#  'opinion': ['  Me alojé recientemente en el Holiday Inn de Zócalo, situado en '
#              'la zona histórica de la ciudad. Está ubicado justo en la plaza '
#              'histórica, a dos manzanas del metro y cerca de muchos '
#              'restaurantes por los alrededores y las tiendas y. Las '
#              'habitaciones, al menos la que tuve era pequeño y compacto, una '
#              'TV agradable, cama grande, ducha en el baño. La habitación está '
#              'impecable, extremadamente limpio, y bien cuidado. Mi habitación '
#              'daba a la calle, de 5 Cinco de Mayo. El vestíbulo era agradable, '
#              'con un pequeño bar, y servicio de Internet, gratis, limitado a '
#              '30 minutos al día, después de eso, está a 50 pesos, puedes '
#              'encontrar sitios mucho más baratas de Internet en toda la '
#              'ciudad. El personal era amable. Dos manzanas la calle en 5 Cinco '
#              'de Mayo y en el mismo lado de la calle, era un gran',
#              '…']}
# 2021-04-01 21:14:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or1200-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_50'],
#  'fecha': [' mayo de 2006'],
#  'nombre': ['Traveler10315'],
#  'opinion': ['Nos alojamos por tres noches y me gustaría quedado más tiempo! '
#              'La ubicación es impresionante, y nos encantó ver fuera y ver el '
#              'lado histórico de la ciudad! El hotel está en excelentes '
#              'condiciones, y muy bonito. El baño es muy confortable y la '
#              'habitación en gran forma y súper limpio. La zona no es peligrosa '
#              'y que era una maravilla para caminar. Yo definitivamente me '
#              'quedaría aquí cada vez que volver. El buffet de desayuno era '
#              'delicioso y la terraza de la azotea era genial tener vistas a '
#              'bautiful de Ciudad de México. El servicio era excepcional. ¡Todo '
#              'el mundo era muy amable en todo momento del día. ']}
# 2021-04-01 21:14:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or1200-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_40'],
#  'fecha': [' abril de 2005'],
#  'nombre': ['Patricia_Wells'],
#  'opinion': ['  Un hotel estupendo, limpio y una gran terraza en la azotea con '
#              'un restaurante bastante decente. Está cerca de todo en el centro '
#              'Historica distrito. Bien para pillar un autobús turístico y una '
#              'entrada para metro en frente de la Catedral. El personal es muy '
#              'servicial. Y las habitaciones son en realidad bastante grande y '
#              'era espaciosa para ser un hotel no- USA, nos pasaron a una suite '
#              'Junoir   Me alojaría aquí de nuevo.    ']}
# 2021-04-01 21:14:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or1195-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html> (referer: https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or1210-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html)
# 2021-04-01 21:14:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or1195-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_20'],
#  'fecha': [' diciembre de 2007'],
#  'nombre': ['texmacge'],
#  'opinion': ['El Holiday Inn de Zócalo está situado en el centro histórico de '
#              'Ciudad de México cruzando la calle de la plaza (Zócalo) y la '
#              'catedral nacional. Es un fantástico lugar para visitar las '
#              'ruinas Aztec (Templo mayor) y el Govenor es Palace (Reviera '
#              'Diego de murales). Hay muchas tiendas y restaurantes a una corta '
#              'distancia a pie.  El personal del hotel es muy amable y '
#              'servicial y nuestra habitación estaba muy limpia y cómoda. El '
#              'restaurante de la azotea ofrece unas fantásticas vistas de la '
#              'Zócalo y la ciudad.  Hay unas cuantas cosas que uno debería '
#              'considerar si elige este hotel.  Primero, si tienes una '
#              'habitación cerca del Zócalo. la Aztecs será anoy, con sus muy '
#              'ruidoso fuerte hasta las 10:00 o las 11:00h. El drum es tan alto '
#              'que lo que no sólo oíamos, pero cree que también. Llevé a',
#              '…']}
# 2021-04-01 21:14:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or1195-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_40'],
#  'fecha': [' noviembre de 2007'],
#  'nombre': ['KenTom'],
#  'opinion': ['Sólo pasé 5 noches en el Holiday Inn de Zócalo y no tengo '
#              'quejas. Reservamos una "Junior  Suite", que es una habitación '
#              'más grande con una ventana en el Zócalo. Lo único malo es que '
#              'Conchero de los bailarines en el Zócalo a toda la noche de los '
#              'sábados. Nos encontramos a encendíamos el aire acondicionado o '
#              'de calor, creado un "ruido blanco" que ayudaba a bloquear el sin '
#              'parar fuerte. Hotel tiene internet sin cables gratis, así que si '
#              'viajas con portátil con es una característica estupenda. '
#              'Desktops disponibles para uso de los huéspedes en el vestíbulo. '
#              'El personal era genial. El desayuno en la terraza es muy bonita, '
#              'pero un poco caro. Hotel Majestic hace lo mismo al igual que el '
#              'Gran Hotel. Para un desayuno mexicano real más barato ve a cinco '
#              'de mayo a Casa de los Ángeles',
#              '…']}
# 2021-04-01 21:14:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or1195-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_40'],
#  'fecha': [' febrero de 2007'],
#  'nombre': ['Arequipa'],
#  'opinion': ['Nos alojamos felices en el Holiday Inn de Zócalo para cuatro '
#              'noches entre las excursiones de Guatemala y México. Nos quedamos '
#              'muy contentos con la ubicación al lado de la plaza principal '
#              '(Palacio Nacional, Diego Rivera murales, la catedral, Templo '
#              'mayor y museo) y muchos buenos restaurantes. Tenía la sexta '
#              'planta parcialmente cubierta restaurante (la parte había tenido '
#              'sombrillas) de la azotea, que daba a la plaza y tenía muy '
#              'bonitas vistas. Comimos el desayuno sólo allí, pero era '
#              'delicioso y con una gran variedad de platos mexicanos y '
#              'americanos, bien fruta, cereales, yogur y huevos cocinados a la '
#              'orden.  Hay dos paradas de metro cerca, así que es fácil acceso '
#              'para el resto de la ciudad.  Las habitaciones estaban en la '
#              'pequeña, lados, pero estaba impecablemente limpio y',
#              '…']}
# 2021-04-01 21:14:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or1195-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_40'],
#  'fecha': [' enero de 2007'],
#  'nombre': ['Chompie'],
#  'opinion': ['Gran ubicación, bonito hotel. El restaurante en el tejado con '
#              'vistas a la Zócalo es maravilloso con bastante buena comida. El '
#              'desayuno es muy bueno. ']}
# 2021-04-01 21:14:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or1195-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_40'],
#  'fecha': [' junio de 2006'],
#  'nombre': ['Scottsicle'],
#  'opinion': ['  Para aquellos de vacaciones a Ciudad de México, no puedes '
#              'conseguir algo mejor que este hotel encantador. Su ubicación es '
#              'perfecta, con vistas de una hermosa catedral, el palacio '
#              'nacional, las ruinas de las pirámides culturas aztecas, y una de '
#              'las plazas más grandes en el mundo. Los puntos más históricos y '
#              'culturales están a tiro de piedra de los que podíamos '
#              'posiblemente ver en nuestra estancia de cinco días. Llegamos en '
#              'la noche, y cenamos en la terraza en el restaurante del hotel, '
#              'daba sobre el centro histórico y las libre se ilumina con las '
#              'luces de la ciudad. Una vista impresionante para cualquier '
#              'estándar. En junio de última hora es en la temporada de lluvias, '
#              'el aire acondicionado estaba bastante limpia. El buffet de '
#              'desayuno del hotel es abundante y delicioso, y los',
#              '…']}
# 2021-04-01 21:14:39 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or1190-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html> (referer: https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or1210-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html)
# 2021-04-01 21:14:39 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or1190-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_20'],
#  'fecha': [' diciembre de 2008'],
#  'nombre': ['stickerj'],
#  'opinion': ['  Un lugar excelente para alojarse si estás un monje. Nuestra '
#              'habitación era minúscula y estaban desnudas. Cuando nos acabaron '
#              'de agua mineral gratis que tuve que ir a la recepción. La '
#              'habitación estaba impecable pero el precio es alto cuando '
#              'comparado con hotel Catedral o Gillow. Nos fuimos después de la '
#              'primera noche.  ']}
# 2021-04-01 21:14:39 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or1190-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_40'],
#  'fecha': [' diciembre de 2008'],
#  'nombre': ['jfpTexas'],
#  'opinion': ['Nos quedamos allí para 2 noches justo antes de Navidad y que fue '
#              'muy concurrida. El personal era muy cortés, servicial y '
#              'simpático. El servicio de internet era genial. Me volvería a ser '
#              'dispuesto a alojar allí de nuevo pero no en temporada navideña. '
#              'Nos encantó el desayuno en la terraza...']}
# 2021-04-01 21:14:39 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or1190-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_50'],
#  'fecha': [' julio de 2008'],
#  'nombre': ['g0g'],
#  'opinion': ['  Este lugar es perfecto para turistas que quieran explorar la '
#              'ciudad. Sin duda merece la pena pagar ese poquito más por una de '
#              'las habitaciones con vistas a la plaza, puedes ver la playa '
#              'ondeaba yendo hacia arriba y hacia abajo (incluido ceremonia y '
#              'el ejército) cada día. El desayuno en la terraza es un comienzo '
#              'estupendo para el día. La comida es buena y si tienes un asiento '
#              'en el borde de la terraza hay los colibríes (yo creo) en un '
#              'vuelo! La terraza es un lugar genial para la cena! El personal '
#              'del hotel (especialmente José Luis) fueron servicial organizando '
#              'excursiones (aseguraos de visitar las pirámides) y ofrecían '
#              'recomendaciones. Nos sentimos muy seguros en las calles cercanas '
#              'en la noche y había policía en cada esquina.  ']}
# 2021-04-01 21:14:39 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or1190-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_40'],
#  'fecha': [' agosto de 2007'],
#  'nombre': ['LifeofLeisure'],
#  'opinion': ['Disfruté de mi estancia en el Holiday Inn de Zócalo. No es el '
#              'hotel gastarme en Ciudad de México, pero está limpio y tiene una '
#              'terraza increíble restaurante de la azotea con vistas a Zócalo '
#              'Plaza. Hay restaurantes estupendos a una corta distancia a pie '
#              '(Opera, y el café Tacuba) . También se puede ir a pie es el '
#              'Palacio Nacional (con murales de Diego Rivera) y el Palacio de '
#              'Bellas Artes. Hay internet gratis en los ordenadores en el '
#              'vestíbulo y sin cables en las habitaciones. Desventajas: (1) '
#              'muchos de los miembros del personal de la limpieza no hablan '
#              'inglés bien, que puede ser molesto si tienes que no hablan '
#              'español, (2) el servicio en el restaurante no es coherente -- a '
#              'veces es realmente genial y, entonces los demás lento con '
#              'errores en el orden, (3) en ocasiones, el servicio',
#              '…']}
# 2021-04-01 21:14:39 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or1190-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_40'],
#  'fecha': [' abril de 2008'],
#  'nombre': ['Hemster7'],
#  'opinion': ['  Nos alojamos aquí por una semana durante 28AOR08 a 3MAY08.   '
#              'En general, este hotel es de una muy buena relación '
#              'calidad-precio. La ubicación es inmejorable ya que puedes ir '
#              'andando a todas partes en 10 minutos.     Durante mi estancia el '
#              'bar del vestíbulo estaba de reformas y el bar del restaurante no '
#              'tenía ambiente. La comida está bien, no excelente pero sólo '
#              'promedio. servicio está por debajo de la media. Dicho esto, no '
#              'hay que alojarse en el hotel para las comidas como hay unos '
#              'restaurantes excelentes en la vecindad. Lo recomiendo altamente '
#              'el famoso café Tacuba bien, así como la El vegetariano excelente '
#              'en Filomeno Mata (a unos 5 minutos a pie).     A una corta '
#              'distancia a pie son los antiguos templos (Templo Mayor) así como '
#              'varias catedrales antiguas. La vieja ciudad',
#              '…']}
# 2021-04-01 21:14:39 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or1185-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html> (referer: https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or1210-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html)
# 2021-04-01 21:14:39 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or1185-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_10'],
#  'fecha': [' noviembre de 2010'],
#  'nombre': ['bajapi'],
#  'opinion': ['Este hotel es probablemente el peor Holiday Inn en el que me '
#              'alojé en. Yo soy un Holiday Inn miembro de categoría "platinum" '
#              'y he estado aquí antes, pero esta vez que tuve que debido a la '
#              'ubicación de poder ir andando a mis reuniones. La habitación que '
#              'me dieron era no más grande que mi a pie en un armario en casa. '
#              'Yo soy 6" alto y mis pies estaban colgando sobre la cama. El '
# ...
#              'excelente. Como por la comida, te puedo decir que está bien, '
#              'pero deberían variar su menú porque tener sólo tres opciones '
#              'para el desayuno no es suficiente, aunque puedan preparar '
#              'prácticamente cualquier cosa que pidas. Porque está tan cerca de '
#              'Zócalo puede experimentar algún grado leve de ruido, tales como '
#              "la policía 'silbidos y tambores desde bailarines locales pero no "
#              'una importante preocupación para ser honesto (odio a dormir en '
#              'lugares ruidosos y este es tolerable). Ah! Casi me olvidé de '
#              'decir que estas habitaciones son pequeñas, como es de esperar '
#              'para estar en una buena ubicación.']}
# 2021-04-01 21:24:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or600-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html> (referer: https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or595-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html)
# 2021-04-01 21:24:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tripadvisor.com.mx/RegistrationController?flow=sign_up_and_save&returnTo=%2FHotel_Review-g150800-d185401-Reviews-or590-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html&fullscreen=true&flowOrigin=login&hideNavigation=true> (referer: https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or590-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html)
# 2021-04-01 21:24:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or600-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_50'],
#  'fecha': [' marzo de 2017'],
#  'nombre': ['Mary B'],
#  'opinion': ['El hotel está situado en el corazón de CDMX. Está a corta '
#              'distancia a pie de la Catedral Metropolitana, el zócalo, Palacio '
#              'Nacional, el Templo Mayor, el Palacio de Bellas Artes, y varios '
#              'otros lugares. También hay un montón de tiendas y restaurantes '
#              'alrededor del hotel. El balcón de zócalo restaurante está en la '
#              'planta 6ª y tiene una vista fantástica de la plaza Zócalo. No me '
#              'arrepiento de mi estancia en este hotel. Tuve el 5 de mayo ver '
#              'desde mi habitación. Parecía bastante por la noche. Nos dio una '
#              'sensación colonial maquillado. También era bastante. Me encanta '
#              'que mi habitación está bien limpia cada vez que vuelves de una '
#              'excursión de un día. Era tan refrescante! También hay manzanas '
#              'gratis y una botella de agua helada para cualquiera que quiera '
#              'uno. Yo siempre tenía una',
#              '…']}
# 2021-04-01 21:24:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or600-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_30'],
#  'fecha': [' abril de 2017'],
#  'nombre': ['Angel57'],
#  'opinion': ['Nos alojamos 3 noches aquí como parte de un tour de viajes de '
#              'México. Llama El hotel está muy bien ubicado y el personal '
#              'agradable. Pedimos una habitación tranquila, doble y nos '
#              'pusieron una de las mayores habitaciones de estilo con vistas al '
#              'patio interior y una pequeña cafetería en la parte de abajo. '
#              'Ruido de la gente en la zona de cafetería de abajo no me molestó '
#              'durante la noche y las paredes de la habitación son bastante '
#              'finas. Las camas eran muy cómodas. El desayuno incluido estaba '
#              'bien. En general una estancia confortable.']}
# 2021-04-01 21:24:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or600-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_50'],
#  'fecha': [' abril de 2017'],
#  'nombre': ['surgmars'],
#  'opinion': ['El hotel goza de una ubicación perfecta para cualquier cosa que '
#              'quieras hacer en la plaza principal de el zócalo. El hotel está '
#              'maravillosamente decorado y todos los detalles maravillosamente '
#              'logrado. El personal es extremadamente servicial. Te cuidan, '
#              'como si fueras de la familia. Rodrigo y Lalo nos sirvieron el '
#              'desayuno y siempre fue muy agradable con nosotros. El menú de '
#              'desayuno es muy bueno, especialmente las manzanas siempre '
#              'disfrutamos todos los días y el agua fría embotellada también '
#              'era un toque agradable sin cargo extra. Este hotel no tiene un '
#              'restaurante en la azotea, pero su hermano no que está al otro '
#              'lado del Zócalo, y a sólo unas manzanas de distancia. Gran '
#              'estancia!']}
# 2021-04-01 21:24:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or600-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_40'],
#  'fecha': [' abril de 2017'],
#  'nombre': ['ryokogasuki'],
#  'opinion': ['Este hotel está a sólo 100 m de Zócalo, la plaza principal '
#              'frente a la catedral. Es de 7 pisos de altura con un restaurante '
#              'con terraza muy agradable en la parte superior. Tuvimos una '
#              'habitación estándar con 2 camas individuales. La habitación era '
#              'pequeña pero funcional. Las camas estaban en el lado estrecho. '
#              'El servicio era muy bueno, pero uno de los empleados de la '
#              'recepción nos dio información incorrecta en 2 casos (el trayecto '
#              'en taxi desde el aeropuerto, estado de reserva en el restaurante '
#              '"Terraza de El Balcón"). Tienen coches que cobran 250 pesos al '
#              'aeropuerto. Si su vuelo es temprano y no puede llevar la ventaja '
#              'del desayuno gratuito, puedes pedir un paquete que consta de un '
#              'sándwich, una manzana y una botella de agua.']}
# 2021-04-01 21:24:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or600-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_50'],
#  'fecha': [' abril de 2017'],
#  'nombre': ['dpb_53'],
#  'opinion': ['Zócalo Central Hotel es un maravilloso hotel situado en el '
#              'corazón de CDMX. El hotel es muy limpio, muy bien organizado y '
#              'todo funciona! El personal es extremadamente amable y conocedor. '
#              'Un maravilloso desayuno se sirve en la planta 6ª del hotel en el '
#              'restaurante Balcón de zócalo, con vistas al Palacio Nacional. '
#              'Gracias en especial a Eduardo quien organizado muchas de '
#              'nuestras excursiones.']}
# 2021-04-01 21:24:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or610-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html> (referer: https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or620-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html)
# 2021-04-01 21:24:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or610-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_50'],
#  'fecha': [' abril de 2017'],
#  'nombre': ['Victor G'],
#  'opinion': ['Excelente servicio. El personal de recepción era amable. Saludó '
#              'con apple fresco y una variedad de agua o bebida y toalla de '
#              'mano fuit. La habitación estaba limpia y la cama muy cómoda. '
#              'Restaurante de la azotea tiene buena comida y excelente '
#              'servicio, con una gran vista del Zócalo. La ubicación es '
#              'perfecta.']}
# 2021-04-01 21:24:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tripadvisor.com.mx/RegistrationController?flow=sign_up_and_save&returnTo=%2FHotel_Review-g150800-d185401-Reviews-or620-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html&fullscreen=true&flowOrigin=login&hideNavigation=true> (referer: https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or620-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html)
# 2021-04-01 21:24:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or610-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_50'],
#  'fecha': [' marzo de 2017'],
#  'nombre': ['seichorn'],
#  'opinion': ['Aunque técnicamente era un hotel de cuatro estrellas, este hotel '
#              'tiene un ambiente de cinco estrellas. Nunca me molestó escrito '
#              'estos comentarios, pero yo estaba súper impresionado con el '
#              'personal atento y servicial. Tiene un muy buen restaurante en la '
#              'azotea con vistas a la Catedral y la plaza Zócalo. Realmente ir '
#              'más allá y por encima de muchos niveles de la OMI. Si estás '
#              'buscando un hotel excelente que tiene un ambiente de lujo en '
#              'lugar de una de las cadenas hoteleras, creo que no te puedes '
#              'equivocar con este. Si el desayuno está incluido (parecía el '
#              'caso para todo el mundo), es un auténtico desayuno con personal '
#              'con huevos, zumo de naranja recién exprimido, etc. Y no sólo en '
#              'un desayuno continental. El hotel está situado en el centro del '
#              'distrito histórico.']}
# 2021-04-01 21:24:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or610-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_50'],
#  'fecha': [' diciembre de 2016'],
#  'nombre': ['KerchieArndTheWorld'],
#  'opinion': ['Nos alojamos en el Zócalo antes de ir a una boda en Morelia. La '
#              'habitación era exactamente como se anuncia. Nuestro único '
#              'problema fue que era bastante pequeña, dicho esto el tamaño de '
#              'la habitación era claramente anunciado.  El personal siempre fue '
#              'muy amable y la ubicación es casi imposible de superar, '
#              'especialmente por el precio.  Aunque no pudimos comer en el '
#              'restaurante de nuestros amigos, no la noche anterior. Son gente '
#              'y comentó el hecho de que fue uno de los mejores restaurantes en '
#              'los alrededores.  Sin duda lo recomendaría y volvería de nuevo.']}
# 2021-04-01 21:24:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or610-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_40'],
#  'fecha': [' marzo de 2017'],
#  'nombre': ['Renzi36'],
#  'opinion': ['Mi marido y yo pasamos 3 noches en este precioso hotel. Nuestra '
#              'habitación estaba bien amueblada, estaba limpia y tenía un '
#              'bonito baño. (El único problema era que parecía que oímos cada '
#              'wc en el lugar tirar por la noche. WiFi) es buena y el personal '
#              'es profesional y atento.  Nuestra cama era un doble estándar, '
#              'que es demasiado pequeña para nosotros, pero esa fue nuestra '
#              'culpa no estipulan que necesitábamos una cama más grande. '
#              'Asegúrate de que no!  El desayuno incluido era muy buena y la '
#              'vista hizo la estancia especial. Se sirve el desayuno y otras '
#              'comidas (si desea) en el balcón mirando directamente a la '
#              'Catedral y a la plaza.  La ubicación era céntrica para todo y '
#              'era muy fácil para nosotros para salir y estar en el centro de '
#              'la acción. Cerca de restaurantes, tiendas,',
#              '…']}
# 2021-04-01 21:24:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or610-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_50'],
#  'fecha': [' octubre de 2016'],
#  'nombre': ['Clau A'],
#  'opinion': ['Justo en frente del Zócalo, este lugar tiene una ubicación '
#              'maravillosa. Las habitaciones son pequeñas pero cómodas y '
#              'limpias. El restaurante del hotel es realmente genial, con un '
#              'delicioso menú y una gran selección de vinos y bebidas '
#              'mexicanas. Disfruté de mi estancia en este hotel y lo recomiendo '
#              'encarecidamente']}
# 2021-04-01 21:24:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tripadvisor.com.mx/RegistrationController?flow=sign_up_and_save&returnTo=%2FHotel_Review-g150800-d185401-Reviews-or615-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html&fullscreen=true&flowOrigin=login&hideNavigation=true> (referer: https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or615-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html)
# 2021-04-01 21:24:13 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tripadvisor.com.mx/RegistrationController?flow=sign_up_and_save&returnTo=%2FHotel_Review-g150800-d185401-Reviews-or605-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html&fullscreen=true&flowOrigin=login&hideNavigation=true> (referer: https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or605-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html)
# 2021-04-01 21:24:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tripadvisor.com.mx/RegistrationController?flow=sign_up_and_save&returnTo=%2FHotel_Review-g150800-d185401-Reviews-or600-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html&fullscreen=true&flowOrigin=login&hideNavigation=true> (referer: https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or600-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html)
# 2021-04-01 21:24:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tripadvisor.com.mx/RegistrationController?flow=sign_up_and_save&returnTo=%2FHotel_Review-g150800-d185401-Reviews-or610-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html&fullscreen=true&flowOrigin=login&hideNavigation=true> (referer: https://www.tripadvisor.com.mx/Hotel_Review-g150800-d185401-Reviews-or610-Zocalo_Central-Mexico_City_Central_Mexico_and_Gulf_Coast.html)
# 2021-04-01 21:24:15 [scrapy.core.engine] INFO: Closing spider (finished)
# 2021-04-01 21:24:15 [scrapy.extensions.feedexport] INFO: Stored csv feed (1207 items) in: ZocaloCentralHotel_Trip.csv
# 2021-04-01 21:24:15 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 1893703,
#  'downloader/request_count': 485,
#  'downloader/request_method_count/GET': 485,
#  'downloader/response_bytes': 93436814,
#  'downloader/response_count': 485,
#  'downloader/response_status_count/200': 485,
#  'dupefilter/filtered': 1700,
#  'elapsed_time_seconds': 593.197204,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2021, 4, 2, 3, 24, 15, 964110),
#  'item_scraped_count': 1207,
#  'log_count/DEBUG': 1693,
#  'log_count/INFO': 20,
#  'log_count/WARNING': 1,
#  'request_depth_max': 61,
#  'response_received_count': 485,
#  'scheduler/dequeued': 485,
#  'scheduler/dequeued/memory': 485,
#  'scheduler/enqueued': 485,
#  'scheduler/enqueued/memory': 485,
#  'start_time': datetime.datetime(2021, 4, 2, 3, 14, 22, 766906)}
# 2021-04-01 21:24:15 [scrapy.core.engine] INFO: Spider closed (finished)
