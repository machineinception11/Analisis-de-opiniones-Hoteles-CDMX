# %% [markdown]
# # Extracción de Opiniones Hotel 4.	HostelMundoJoven ($389)

# %%
# Importamos librerias
from time import sleep
import pandas as pd
import random
from scrapy.item import Item
from scrapy.item import Field
from scrapy.spiders import CrawlSpider, Rule
from scrapy.loader import ItemLoader
from scrapy.linkextractors import LinkExtractor
from scrapy.selector import Selector
from scrapy.crawler import CrawlerProcess

# %%
class Opiniones(Item):
    nombre = Field()
    opinion = Field()
    calificacion = Field()
    fecha = Field()
    
class Hotel(CrawlSpider):
    # Definimos el nombre del spider
    name = "MumediDesignHotel"
    
    # Definimos la seguridad para no sér detectados
    custom_settings = ({
        "USER_AGENT": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.77 Safari/537.36"
    })
    
    # Tiempo de descarga
    download_delay = 1
    
    # ¿De dónde extraerémos los datos?
    start_urls = ["https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html"]
    
    # ¿Qué páginas están permitidas?
    allowed_domain = ["tripadvisor.com.mx"]
    
    # Definimos las reglas
    # Scraping horizontal
    rules = (
        Rule(
            LinkExtractor(
                allow = r'-or\d+'
            ), follow = True, callback = 'parse_opiniones'
        ),
    )
    
    # Definimos la función para el parseador
    def parse_opiniones(self, response):
        sel = Selector(response)
        # opiniones = sel.xpath('//div[@data-test-target="reviews-tab"]/div[@data-test-target = HR_CC_CARD]')
        opiniones = sel.xpath('//div[@id = "taplc_resp_hr_ad_wrapper_lower_block_0"]/div/div/div/div/div/div[3]/div[@data-test-target="HR_CC_CARD"]')
        
        for opinion in opiniones:
            item = ItemLoader(Opiniones(), opinion)
            item.add_xpath('nombre', './/a[@class = "ui_header_link _1r_My98y"]/text()')
            item.add_xpath('opinion', './/q[@class = "IRsGHoPm"]/span/text()') 
            item.add_xpath('calificacion', './/div[@data-test-target = "review-rating"]/span[contains(@class, "ui_bubble_rating")]/@class')
            item.add_xpath('fecha', './/span[@class = "_34Xs-BQm"]/text()') 
            
            yield item.load_item()

# %%
process = CrawlerProcess({
    "FEED_FORMAT": "csv",
    "FEED_URI": "HostelMundoJoven_Trip.csv"
})

process.crawl(Hotel)
process.start()
# Out:
# 2021-04-01 22:46:48 [scrapy.utils.log] INFO: Scrapy 2.4.1 started (bot: scrapybot)
# 2021-04-01 22:46:49 [scrapy.utils.log] INFO: Versions: lxml 4.6.1.0, libxml2 2.9.10, cssselect 1.1.0, parsel 1.5.2, w3lib 1.21.0, Twisted 21.2.0, Python 3.7.7 (default, May  6 2020, 11:45:54) [MSC v.1916 64 bit (AMD64)], pyOpenSSL 19.1.0 (OpenSSL 1.1.1k  25 Mar 2021), cryptography 3.2.1, Platform Windows-10-10.0.19041-SP0
# 2021-04-01 22:46:49 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2021-04-01 22:46:49 [scrapy.crawler] INFO: Overridden settings:
# {'USER_AGENT': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 '
#                '(KHTML, like Gecko) Chrome/70.0.3538.77 Safari/537.36'}
# 2021-04-01 22:46:49 [scrapy.extensions.telnet] INFO: Telnet Password: 0ab325e26afe0e9e
# 2021-04-01 22:46:49 [py.warnings] WARNING: D:\Anaconda\lib\site-packages\scrapy\extensions\feedexport.py:247: ScrapyDeprecationWarning: The `FEED_URI` and `FEED_FORMAT` settings have been deprecated in favor of the `FEEDS` setting. Please see the `FEEDS` setting docs for more details
#   exporter = cls(crawler)
#
# 2021-04-01 22:46:49 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2021-04-01 22:46:49 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2021-04-01 22:46:49 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2021-04-01 22:46:49 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2021-04-01 22:46:49 [scrapy.core.engine] INFO: Spider opened
# 2021-04-01 22:46:49 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2021-04-01 22:46:49 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2021-04-01 22:46:51 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html> (referer: None)
# 2021-04-01 22:46:53 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or5-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html> (referer: https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html)
# 2021-04-01 22:46:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or5-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_30'],
#  'fecha': [' septiembre de 2019'],
#  'nombre': ['viajera029'],
#  'opinion': ['El hostal está detrás de la Catedral y tiene 2 estaciones de '
#              'metro muy cerca, caminando recorres el centro histórico, museo '
#              'bellas artes, Alameda Central y la calle Madero, todo muy bonito '
#              'pero no sabíamos que los fines de semana cierran el acceso al '
#              'zócalo desde las 10 pm porque allí está el palacio de gobierno. '
#              'Llegamos del aeropuerto a las 12.30 y el taxi no tenía cómo '
#              'entrar y dejarnos en el hostal, lo más cercano fue 4 cuadras y '
#              'estaba muy oscuro y solitario, hay muchos patrullemos alrededor '
#              'del zócalo pero no en las calles aledañas y caminar con maletas '
#              'fue una experiencia desagradable, felizmente estaban los que '
#              'hacen limpieza y no estábamos tan solas. Es algo a tomar en '
#              'cuenta si van a regresar tarde solo podrán en metro.  Tomamos un '
#              'cuarto privado y es muy pequeño, los',
#              '…']}
# 2021-04-01 22:46:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or5-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_10'],
#  'fecha': [' agosto de 2019'],
#  'nombre': ['Maite M'],
#  'opinion': ['El hotel huele horrible a caño, los baños sucios y apestan, no '
#              'los lavan bien, MUCHO ruido!! Porque el bar del hotel está '
#              'arriba y todos se escucha en todos los pisos, además de que los '
#              'huéspedes hacen fiesta en sus cuartos esto no deberían '
#              'permitirlo! Las sábanas sucias me toco mi funda manchada de '
#              'sangre, el trato del personal es grosero y no les interesa tener '
#              'un buen trato al huésped le dan más prioridad a los que vienen a '
#              'las fiestas!! Me tocó que en el quinto piso cierran los baños '
#              'con llave hay que bajar a otros pisos para poder usar el baño !']}
# 2021-04-01 22:46:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or5-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_40'],
#  'fecha': [' febrero de 2019'],
#  'nombre': ['Denise C'],
#  'opinion': ['Es la tercera vez que me hospedo, las habitaciones son cómodas y '
#              'amplias y los baños también. El desayuno tiene cereales, panes, '
#              'jamón, queso, huevos. La cocina es cómoda, tiene elementos para '
#              'cocinar y si no, hay un restobar al ingreso con buenos precios y '
#              'opciones. La terraza es preciosa, un buen lugar para reunirse '
#              'con otros huéspedes y además hay un bar para la tardecita/noche '
#              'que pasa buena música. La ubicación es ideal para moverse a pie '
#              'por el zócalo y los lugares del centro histórico, tenés el metro '
#              'a una cuadra y en la puerta la parada del bus turístico. Hay '
#              'además en la recepción, una agencia de turismo que ofrece muy '
#              'buenas opciones para recorrer DF o lugares cercanos. Tantos los '
#              'chicos de la recepción, del desayuno y de la agencia son muy '
#              'amables y dispuestos a',
#              '…']}
# 2021-04-01 22:46:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or5-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_40'],
#  'fecha': [' junio de 2019'],
#  'nombre': ['MoonkyPlata'],
#  'opinion': ['La ubicación es de lo mejor! A poca distancia de la estación del '
#              'metro y de la calle Madero y sus tiendas y negocios. El que '
#              'tenga ascensor es un plus que se agradece sobre todo cuando '
#              'estás tan cansado y con muchas y pesadas maletas! El desayuno es '
#              'muy muy básico, limitado pero aceptable. El personal de '
#              'recepción es muy raro, en mi check in me tocó un chico super '
#              'amable y carismático pero el resto de los chicos se muestran '
#              'desinteresados y un poco fastidiados de atender a los huéspedes. '
#              'La peor del personal es esa señora gorda de cabello medio rizado '
#              'color café que está en el restaurant y si le preguntas algo te '
#              'mira cómo si no trabajara ahí y todavía hasta voltea los ojos y '
#              'hace muecas, definitivamente odia su trabajo! Es una pena que la '
#              'terraza sólo esté abierta en la tardes',
#              '…']}
# 2021-04-01 22:46:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or5-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_30'],
#  'fecha': [' abril de 2019'],
#  'nombre': ['Kathe D'],
#  'opinion': ['El lugar queda en una muy buena ubicación, al respaldo de la '
#              'catedral metropolitana. Tienes la visión desde la terraza a la '
#              'plaza del zócalo y la catedral. Fácil acceso al metro. '
#              'Habitaciones limpias y cuentan con servicio de desayuno.']}
# 2021-04-01 22:46:53 [scrapy.dupefilters] DEBUG: Filtered duplicate request: <GET https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or5-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html> - no more duplicates will be shown (see DUPEFILTER_DEBUG to show all duplicates)
# 2021-04-01 22:46:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or405-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html> (referer: https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html)
# 2021-04-01 22:46:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or405-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_40'],
#  'fecha': [' febrero de 2012'],
#  'nombre': ['missrach_walk'],
#  'opinion': ['El hostal está situado en una gran ubicación, esto es lo mejor '
#              'del hostal. Nos alojamos en una habitación de 4 dormitorios cama '
#              'que era tan pequeño, afortunadamente nuestros otros dos colegas '
#              'de nuestra habitación nunca estuvimos y teníamos la habitación '
#              'para nosotros 2 noches. El baño compartido con otra habitación '
#              'estaba bien limpio y buena ducha caliente. Las camas no eran '
#              'cómodas, muchas fuentes sobresalían por todas partes. Se '
#              'convirtió en soportable tras unas cuantas noches, nos alojamos '
#              'por 5 noches! También era como un túnel de ruido, todas las '
#              'habitaciones tienen estas persianas que dan al medio del hostal '
#              'y puedes mirar hacia abajo para el restaurante. Tienen una regla '
#              'tranquila de tiempo después de las 11 pm, pero era bastante '
#              'ruidoso de la zona de recepción hasta',
#              '…']}
# 2021-04-01 22:46:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or405-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_50'],
#  'fecha': [' diciembre de 2011'],
#  'nombre': ['geronimoturtle'],
#  'opinion': ['Este hostal está situado en una fantástica ubicación detrás de '
#              'la catedral y a poca distancia andando de todo en el centro '
#              'histórico. Hay parques, museos, grandes almacenes y un gran '
#              'supermercado cerca. El hostal es más como un hotel con una '
#              'cocina comunitaria, una máquina de café y asientos al aire libre '
#              'en la terraza con vistas a la plaza principal y un bar en la '
#              'planta superior. El desayuno es bueno, pero por desgracia no '
#              'proporcionan verdadero café como arriba. El personal es amable y '
#              'muy servicial con nuestra remitiese reservas de viajes de '
#              'autobús a Los Mochis. Las habitaciones pueden ser un poco '
#              'ruidosas desde el patio, pero que se vuelve por la noche y no '
#              'nos molestaron. Los baños comunes están limpias pero algunas '
#              'veces no con un poco más de atención a los servicios por',
#              '…']}
# 2021-04-01 22:46:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or405-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_30'],
#  'fecha': [' enero de 2012'],
#  'nombre': ['Don Wright'],
#  'opinion': ['Mundo joven Catedral está excelentemente ubicado justo detrás de '
#              'la Catedral Metropolitana masiva y, por consiguiente, a sólo una '
#              'manzana de la ciudad desde el Zócalo, el Templo Mayor, el '
#              'Palacio Nacional y más. Esto también puede ser la primera '
#              'inconveniente del hostal, porque es el piso más bullicioso '
#              'albergue en el que me he alojado. No sólo por el ruido de la '
#              'calle (tráfico, música, las alarmas de los coches, y la calle '
#              'construcción justo enfrente hasta la medianoche), pero también '
#              'por el ruido dentro del hostal. El patio interior embudos cada '
#              'sonido de recepción y el restaurante del vestíbulo a través de '
#              'todos los suelos del hostal, rebotando sobre pasos y antiguos '
#              'muros de piedra en el camino. Mi pareja y yo estuvimos en la '
#              'suite privada en la 5ª planta, aunque lo',
#              '…']}
# 2021-04-01 22:46:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or405-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_40'],
#  'fecha': [' febrero de 2011'],
#  'nombre': ['megelizah'],
#  'opinion': ['Este era mi primer día en DF. y yo disfrutamos de mi estancia en '
#              'el hostal. No había problema servicial mi llegada aunque llegué '
#              'a las 5 de la mañana. La ubicación es fantástica si quieres '
#              'hacer mucho turismo. La estación de metro de Zócalo era justo a '
#              'la vuelta de la esquina (y yo nos lo tomamos 4/5 días que yo '
#              'estuve allí, una forma estupenda para hacer tu viaje incluso más '
#              'económico) y naturalmente hay lugares de interés justo fuera de '
#              'la puerta. Cuando leí las críticas para el albergue me di cuenta '
#              'de que muchos de quejas sobre ruido del bar/restaurante, pero '
#              'nunca fue un problema, que parece que cierran bastante pronto '
#              '(al menos durante la semana). Me quitaron un poco de problemas '
#              'para dormir por culpa del ruido del tráfico y la calle (mi '
#              'habitación daba a la catedral) pero',
#              '…']}
# 2021-04-01 22:46:55 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or25-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html> (referer: https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html)
# 2021-04-01 22:46:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or25-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_40'],
#  'fecha': [' mayo de 2018'],
#  'nombre': ['tcgallegosgonzalez'],
#  'opinion': ['Si quieres viajar a la ciudad de medico, conocer los mejores '
#              'sitios turísticos y no gastar tanto este es una excelente '
#              'opción, su ubicación te permite moverte caminando a todos lados. '
#              'Sin embargo el mismo movimiento que tiene no permite que '
#              'descanses muy bien, suele ser muy ruidoso por el mismo tipo de '
#              'huéspedes que aloja']}
# 2021-04-01 22:46:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or25-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_40'],
#  'fecha': [' abril de 2018'],
#  'nombre': ['Michelle T'],
#  'opinion': ['Muy buena ubicación, precio de habitación accesible, '
#              'habitaciones limpias y gente muy amables. A pesar de que hay un '
#              'bar en la parte alta del edificio, no hay interferencia del '
#              'ruido en la noche. Solamente cambiará el menú de desayuno.']}
# 2021-04-01 22:46:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or25-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_40'],
#  'fecha': [' abril de 2018'],
#  'nombre': ['Kari P'],
#  'opinion': ['Mi estadía en hostel mundo joven estuvo estupenda!! Excelente '
#              'desayuno y atención. Muy buena onda de la gente tanto del '
#              'personal como los huéspedes Muy buena ubicación y la zona es '
#              'segura para caminar de noche']}
# 2021-04-01 22:46:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or25-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_10'],
#  'fecha': [' mayo de 2018'],
#  'nombre': ['Karla M'],
#  'opinion': ['Lo unico bueno: la ubicacion, pero hay mas hostales en la misma '
#              'zona. Todo lo malo. El lugar luce sucio, con poco mantenimiento '
#              'y mejoras, se ven los caños de agua pasar por las habitaciones, '
#              'estas son oscuras, sucias y huelen mal, los baños sucios. '
#              'atencion del personal mala. Pague habitacion con TV y no sirvio '
#              'el sistema de sky. PERO LO PEOR. El excesivo ruido del antro que '
#              'esta arriba del hostal, no solo por la musica, sino que los '
#              'clientes salen gritando carcajeando y echando madres a horas de '
#              'madrugada. PESIMO lugar.']}
# 2021-04-01 22:46:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or25-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_30'],
#  'fecha': [' abril de 2018'],
#  'nombre': ['Jazmin S'],
#  'opinion': ['Reserve tres noches, pero tuve que llegar dos días antes pero la '
#              'primera noche basto para saber que no deseaba quedarme más '
#              'tiempo allí.  Primero mi habitación daba al pasillo entonces '
#              'durante la noche se escucho mucho ruido, la puerta del baño no '
#              'cerraba, es decir; tenias que ir a otro lugar para usar el baño. '
#              'El desayuno es básico, pero aceptable. No tienen el servicio de '
#              'wifi, aunque ves la red en tu teléfono no te facilitan la '
#              'contraseña, pero te dicen que tienen un computador para que lo '
#              'uses y te conectes, sin embargo, no funcionan paginas como '
#              'Booking. Es muy curioso que es mejor hacer la reserva con ellos '
#              'en Booking, si la haces directamente allí debes pagar más, '
#              'cancele las otras noches ya que el personal de recepción no es '
#              'muy amable, debes esperar que hagan cambio de',
#              '…']}
# 2021-04-01 22:46:56 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or20-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html> (referer: https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html)
# 2021-04-01 22:46:57 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or20-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_10'],
#  'fecha': [' julio de 2018'],
#  'nombre': ['Esther S'],
#  'opinion': ['Me dejé olvidado un neceser con mi DNI, tarjeta de crédito y '
#              'bastante dinero. Volví a las pocas horas, sólo había entrado el '
#              'chico de la limpieza,la habitación no había sido ocupada por '
#              'nadie. Cuando habléme con los responsables me dieron largas....y '
#              'no recuperé nada. Un lugar en el que no se hacen responsables de '
#              'algo así no merece la pena']}
# 2021-04-01 22:46:57 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or20-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_50'],
#  'fecha': [' junio de 2018'],
#  'nombre': ['Maria G'],
#  'opinion': ['Nos encantó la ubicación del Hostel, la comodidad y limpieza. '
#              'Solo un poco ruidosa los fines de semana por las fiestas en la '
#              'azotea.  El buffete es bueno pero sugiero que deben poner más '
#              'variedad para que no aburra estar desayunando lo mismo, para las '
#              'personas que su estancia son muchos dias como mi caso.   Pero '
#              'seguro que vuelvo a Hostel Mundo Joven!']}
# 2021-04-01 22:46:57 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or20-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_30'],
#  'fecha': [' junio de 2018'],
#  'nombre': ['Alejandra M'],
#  'opinion': ['Me hospede con mi mamá en este hostal y a pesar de su hermosa '
#              'vista, buen desayuno y acogedora terraza, el trato de las '
#              'personas que te reciben en recepción no es el esperado. El día '
#              'en que llegamos la persona que atendía en la recepción encontró '
#              'un inconveniente en el nombre de la persona que había realizado '
#              'la reserva por booking sin embargo, no nos ofreció ninguna '
#              'solución y su actitud se mostraba bastante déspota.  Los '
#              'camarotes suenan mucho cuando una de las personas se mueve y las '
#              'sábanas que nos entregaron estaban sucias y manchadas. ']}
# 2021-04-01 22:46:57 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or20-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_50'],
#  'fecha': [' diciembre de 2017'],
#  'nombre': ['fer m'],
#  'opinion': ['Volvería sin dudar.  Estuve una semana en el lugar y la terraza '
#              'que tienen es increible, la vista muy bonita. Fueron muy amables '
#              'con nosotros, el desayuno fue regular pero en general lo '
#              'recomiendo. Es muy barato']}
# 2021-04-01 22:46:57 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or20-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_10'],
#  'fecha': [' julio de 2018'],
#  'nombre': ['Andres Felipe Baquero'],
#  'opinion': ['Voy a empezar describiendo lo positivo: está muy bien ubicado, '
#              'incluye desayuno (pan, queso, jugo de limón o yogurth y '
#              'cereales), tiene  cocina y una terraza, es económico y algunos '
#              'miembros del staff son agradables.  Negativo: es muy sucio, no '
#              'hacen buen aseo de zonas comunes, el segundo día se nos callo un '
#              'dulce en la escaleta entre el 2do y 3er piso y después de 3 días '
#              'seguía en el mismo lugar (no limpian!!!), El baño tenía mal '
#              'olor, la ducha tenía mucha basura que no recogían, habían muchos '
#              'sobres de shampoo usados y en la habitación que era para 6 '
#              'personas casi que solo estabamos mi amigo y yo, los camarotes '
#              'son de metal y suenan mucho cuando una de las 2 personas se '
#              'mueve, para acabar de completar, después de quedarnos 5 noches '
#              'en el hostel nos retrasamos 1 hora en hacer',
#              '…']}
# 2021-04-01 22:46:58 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or15-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html> (referer: https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html)
# 2021-04-01 22:46:58 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or15-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_40'],
#  'fecha': [' octubre de 2018'],
#  'nombre': ['Carolin Toloza'],
#  'opinion': ['El Hostal efectivamente cumple con lo que ofrece, dormitorio con '
#              'las comodidades básicas y espacios justos. Aseo suficiente para '
#              'el nivel de uso (nosotras prácticamente solo llegábamos a '
#              'descansar brevemente y dormir. Un desayuno demasiado básico pero '
#              'repito es lo que se ofrece, nada más ni menos. La única queja '
#              'concreta es el ruido excesivo a altas horas a pesar de existir '
#              '“reglas de la casa” y una falta de control absoluta sobre esto, '
#              'por lo que le recomiendo a cualquiera que visite, tapones de '
#              'oído, sino sufrirá por el insomnio.  Lo excelente es el bar de '
#              'la terraza del mismo edificio, con una vista monumental, tragos '
#              'a precios razonables y unasuper buena atención.']}
# 2021-04-01 22:46:58 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or15-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_50'],
#  'fecha': [' mayo de 2018'],
#  'nombre': ['kauldy'],
#  'opinion': ['mi cama tenia vista directa la Zocalo, la verdad estaba muy '
#              'padre, me quede en una habitación de 6 camas con baño dentro de '
#              'la habitación, todo limpio, buen servicio.  me volvería a quedar '
#              'ahí sin duda, les recomiendo que visiten el bar de la terraza, '
#              'tiene una excelente vista.']}
# 2021-04-01 22:46:58 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or15-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_10'],
#  'fecha': [' septiembre de 2018'],
#  'nombre': ['Anni K'],
#  'opinion': ['Mi mala experiencia es por culpa de David, uno de los '
#              'recepcionistas. Trata de una forma totalmente despreciable a los '
#              'huéspedes. No tiene ningún tipo de respeto ni consideración.  '
#              'Una pena poner esta calificación, ya que el resto del staff es '
#              'encantador.   Espero que el manager del hotel tome medidas al '
#              'respecto.']}
# 2021-04-01 22:46:58 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or15-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_50'],
#  'fecha': [' febrero de 2018'],
#  'nombre': ['jcahua16'],
#  'opinion': ['El hostel está ubicado en pleno centro histórico de la CDMX con '
#              'una terraza muy bonita donde ademas de tomar una bebida tiene '
#              'una gran vista y se puede conocer personas de diferentes países. '
#              'Me tocó estar 6 noches con personas increíbles. Roy y Brenda '
#              'eran parte del staff alojados en mi habitación los cuales me '
#              'ayudaron y aconsejaron mucho. El desayuno debería de ser mas '
#              'variado. Agradable estancia']}
# 2021-04-01 22:46:58 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or15-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_10'],
#  'fecha': [' agosto de 2018'],
#  'nombre': ['Carlos B'],
#  'opinion': ['Lo mas desagradable que pueda existir,iba con muchas ilusiones '
#              'de tener una buena impresión del hostal pero mi sorpresa fue un '
#              'cuarto viejo con sábanas viejas y sucias con cucharas en la cama '
#              'demasiado calor en los cuartos no te proporciona ni jabón ni '
#              'tuallas']}
# 2021-04-01 22:46:59 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or10-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html> (referer: https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html)
# 2021-04-01 22:46:59 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or10-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_30'],
#  'fecha': [' febrero de 2019'],
#  'nombre': ['Edgardo Sánchez'],
#  'opinion': ['Los puntos a favor son su ubicación, muy estratégica y céntrica. '
#              'El personal es muy amable y te ayudan con cualquier duda o '
#              'recomendación que necesites. La limpieza y las habitaciones son '
#              'bastante buenas por el precio que ofrecen. La desventaja es que '
#              'para descansar después de un día largo se puede hacer difícil ya '
#              'que la terraza por las noches (sobre todo fines de semana) es un '
#              'bar y se filtra algo de ruido tanto de la música como de las '
#              'personas que llegan.']}
# 2021-04-01 22:46:59 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or10-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_30'],
#  'fecha': [' febrero de 2019'],
#  'nombre': ['nathaliat888'],
#  'opinion': ['Punto Ganador: Ubicado justo en el Zócalo, detrás de la catedral '
#              'metropolitana y es de los hostel Low-Cost. Punto Ganador: '
#              'Ubicado perfecto para tomar el metro (subway) y para tomar los '
#              'autobuses oficiales que hacen los 4 circuitos turisticos en la '
#              'ciudad. Punto NO ganador: Si eres morning-person deberás buscar '
#              'tu desayuno en locales de Avenida Madero o en los alrededores.']}
# 2021-04-01 22:46:59 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or10-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_50'],
#  'fecha': [' enero de 2019'],
#  'nombre': ['Quimbaya'],
#  'opinion': ['El hostel es de lo mejor! Tiene un excelente desayuno, atención, '
#              'limpieza! Todos son muy amables! La ubicación es increíble '
#              'porque está en pleno centro histórico a un paso de todos los '
#              'lugares! Más que recomendable ']}
# 2021-04-01 22:46:59 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or10-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_50'],
#  'fecha': [' noviembre de 2018'],
#  'nombre': ['Amaia T'],
#  'opinion': ['La ubicación es espectacular, en pleno zócalo. Desde la misma '
#              'cama se ve la catedral, una auténtica maravilla!! La terraza es '
#              'verdaderamente espectacular, con un ambiente inmejorable. Y el '
#              'servicio muy bueno, han sido muy amables todos, recepción, bar, '
#              'dirección... De verdad gracias por tratarnos tan bien Joxean, '
#              'Juanito y a los demás!! Nos volveremos a ver.']}
# 2021-04-01 22:46:59 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or10-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_20'],
#  'fecha': [' octubre de 2018'],
#  'nombre': ['Mari Du'],
#  'opinion': ['Lo único destacable del hostel es su ubicación, es genial, salvo '
#              'de noche que no es una zona muy segura y todo cierra temprano, '
#              'incluso para cenar.  Las habitaciones son mínimas, muy básicas. '
#              'El agua de la ducha salió fría siempre...es muy ruidoso y el '
#              'edificio esta viejo y descuidado. Es muy lindo el bar de la '
#              'terraza, pero si queres descansar no es el lugar ideal ya que '
#              'todas lad noches ponen música muy fuerte hasta tarde. ']}
# 2021-04-01 22:46:59 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tripadvisor.com.mx/RegistrationController?flow=sign_up_and_save&returnTo=%2FHotel_Review-g150800-d308512-Reviews-or5-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html&fullscreen=true&flowOrigin=login&hideNavigation=true> (referer: https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or5-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html)
# 2021-04-01 22:47:01 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or395-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html> (referer: https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or405-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html)
# 2021-04-01 22:47:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or395-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_40'],
#  'fecha': [' noviembre de 2012'],
#  'nombre': ['sana_pdc'],
#  'opinion': ['En realidad me alojé allí por segunda vez ahora y tengo que '
#              'decir que es un buen hostal. Como no soy la persona que '
#              'normalmente se hospeda en albergues esta es una muy buena : -) '
#              'El personal es muy amable y servicial. El hostal está limpio, me '
#              'alojé en un albergue (muy poco) de las niñas y tuvimos que '
#              'compartir el baño con otro dormitorio para chicas, así que en '
#              'total 8 chicas con un baño pero estaba bien. me imaginé que '
#              'fuera más difícil. tienes 3 ordenadores que puedes usar gratis, '
#              'acceso gratuito a Internet WIFI, caja fuerte ... Lo único que '
#              'era un poco molesto es que es de alguna manera ruidosa. Me alojé '
#              'en el 2Â° piso y que era bastante ruidosa. la última vez que me '
#              'alojé en la 6ª planta en compartida con 6 personas y que estaba '
#              'bien. La ubicación del hostal es fantástica,',
#              '…']}
# 2021-04-01 22:47:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or395-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_50'],
#  'fecha': [' noviembre de 2012'],
#  'nombre': ['Lisawrightsoul'],
#  'opinion': ['Me quedé muy impresionado con todas las facetas de mi estancia, '
#              'la relación calidad-precio, limpieza, amabilidad y ubicación de '
#              'la Catedral hostal, edificio tiene ascensor, incluido el '
#              'desayuno era bueno. Sin duda me alojaría aquí de nuevo.']}
# 2021-04-01 22:47:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or395-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_40'],
#  'fecha': [' noviembre de 2012'],
#  'nombre': ['suel13'],
#  'opinion': ['Este hostal es muy agradable y en una gran parte de la ciudad de '
#              'México, justo al lado de la plaza principal y Catedral '
#              'Metropolitana. ofrece una buena relación calidad-precio en '
#              'Tours. El hostal tiene habitaciones privadas también, pero '
#              'nosotros nos alojamos en una co-ed habitación para 6. El '
#              'desayuno también está incluido y también hay un restaurante y un '
#              'bar en la azotea que tiene vistas estupendas! Me alojaría aquí '
#              'de nuevo.']}
# 2021-04-01 22:47:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or395-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_40'],
#  'fecha': [' octubre de 2012'],
#  'nombre': ['kayak-atitlan'],
#  'opinion': ['Yo no suelen alojarse en hostales, pero me encontré que necesite '
#              'un lugar para alojarse a corto plazo. Mi conexión de vuelo no '
#              'sucedió, así que yo estaba en la ciudad de México por la noche. '
#              'Me tomó las nuevas Metrobus desde el aeropuerto (otra gran '
#              'oferta), y fuimos buscando un lugar para pasar la noche. Me '
#              'registré en las habitaciones privadas en Mundo joven hostal y '
#              'estaba perfectamente contento con el alojamiento. Puedo '
#              'recomendar este hotel a otros.']}
# 2021-04-01 22:47:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or395-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_50'],
#  'fecha': [' noviembre de 2012'],
#  'nombre': ['Cassie P'],
#  'opinion': ['Este fue el mejor lugar para alojarse en D. F. Estábamos justo '
#              'en la plaza cerca del metro, comida, lugares turísticos, '
#              'tiendas, taxis. era una gran ubicación. Las habitaciones tenían '
#              'armarios para tus cosas y estaba limpio. Desayuno gratuito cada '
#              'mañana. El hostal poner en tours y fue divertido ir con el '
#              'hostal porque teníamos un eficiente y divertido guía y nos '
#              'hicimos muchos amigos. Hay un ordenador y sala de TV, un '
#              'restaurante en el albergue. El personal era muy amable y nos dio '
#              'buenas recomendaciones de lugares para comer. Este lugar me hizo '
#              'nuestra estancia tan increíble. no me hubiera hecho cualquier '
#              'otra manera.']}
# 2021-04-01 22:47:03 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or390-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html> (referer: https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or405-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html)
# 2021-04-01 22:47:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or390-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_50'],
#  'fecha': [' enero de 2013'],
#  'nombre': ['Merrillemma'],
#  'opinion': ['hemos estado también muchos albergues y éste es, de lejos, uno '
#              'de los mejores en los que hemos estado! La ubicación era '
#              'fantástica (justo detrás del Zócalo y la catedral).  La '
#              'habitación estaba limpia y amplia, las duchas estaban calientes. '
#              'La chica en el hostal hablaba muy bien inglés y era muy '
#              'servicial. También nos dio algunas recomendaciones para comer y '
#              'beber. gran lugar para conocer a otros viajeros demasiado ; -) '
#              'El único inconveniente es que la cocina es un poco pequeña y se '
#              'llena bastante concurrido. Sin duda recomendaría este lugar a '
#              'cualquiera que se aloje en la ciudad de México!']}
# 2021-04-01 22:47:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or390-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_40'],
#  'fecha': [' febrero de 2013'],
#  'nombre': ['Mykimike25'],
#  'opinion': ['Me alojé en quiere catedral y me encantó. Los dormitorios son '
#              'pequeñas, así que no es demasiado ruidoso. Las duchas trabajo '
#              'sorprendentemente bien y nunca tuve que esperar para ellos. El '
#              'bar de la azotea es un buen lugar para reunirse con los amigos y '
#              'la remolacha es barato (16 pesos).  cn o relajarse en el k de '
#              'detalles más abajo con sus propias bebidas. Fernando es un tío '
#              'guay que hace los paseos y espectáculos de caminar alrededor. '
#              'verlo.']}
# 2021-04-01 22:47:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or390-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_50'],
#  'fecha': [' enero de 2013'],
#  'nombre': ['JustinConsults'],
#  'opinion': ['todavía recuerdo algunos del personal después de un mes viajando '
#              'ha aprobado. Gracias Fernando y Mel para mostrando mis amigos y '
#              'yo un buen tiempo en varias ocasiones. Me he alojado en muchos '
#              'albergues y este lugar tenía el mejor personal que he conocido. '
#              'También me encantó el bar de la azotea y el gran patio al aire '
#              'libre al lado de la cocina en la 5ª planta. me alojaría aquí de '
#              'nuevo, también una excepcional ubicación.']}
# 2021-04-01 22:47:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or390-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_40'],
#  'fecha': [' diciembre de 2012'],
#  'nombre': ['moniqx'],
#  'opinion': ['Este lugar tiene una ubicación perfecta, que te permite caminar '
#              'por el centro de la ciudad de México, donde hay mucho que ver, y '
#              'buenos lugares para comer, ir de compras y de fiesta. Todo está '
#              'a poca distancia andando y si no, tienes una estación de metro a '
#              'una cuadra de distancia. Las habitaciones privadas son bastante '
#              'pequeñas y un poco de ruido, no demasiado cómoda, pero supongo '
#              'que eso es lo que te dan por ese precio. Wi-fi funcionó bastante '
#              'bien y los chicos de recepción fue muy amable y muy servicial. '
#              'En general, muy buena relación calidad-precio.']}
# 2021-04-01 22:47:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or390-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_40'],
#  'fecha': [' diciembre de 2012'],
#  'nombre': ['HM-Yu'],
#  'opinion': ['La ubicación es perfecta! Está justo en el centro de la ciudad '
#              'de México justo detrás de la iglesia de la Catedral, hay dos '
#              'estaciones de metro cerca del Hoste en 10 minutos andando. Las '
#              'habitaciones y los cuartos de baño son limpios y el personal es '
#              'amable. El desayuno contiene: fruta, pan, café, yogur es básico '
#              'pero bueno.Lo único puede quejarse es un poco ruidoso por la '
#              'noche.Quizás difícil dormir por sueño ligero.']}
# 2021-04-01 22:47:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or385-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html> (referer: https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or405-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html)
# 2021-04-01 22:47:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or385-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_50'],
#  'fecha': [' agosto de 2013'],
#  'nombre': ['Nikki D'],
#  'opinion': ['Esta fue la primera vez que viajaba sola y este hostal todo era '
#              'bueno para mí. muy grande, muy social y hostal es excelente, '
#              'especialmente si queréis conocer a más gente. El personal es muy '
#              'amable y nos hizo un esfuerzo para satisfacer necesidades y '
#              'mochileros eran geniales en organizar excursiones a pie y '
#              'celebrar barbacoas en la azotea, etc. ubicación es perfecta, en '
#              'términos de acceder a otras partes de la ciudad a pie// de '
#              'autobuses metro y consejos siempre determinado de lugares para '
#              'visitar. Las habitaciones son limpias, seguras y el desayuno es '
#              'estupendo! en general, fue una experiencia fantástica y se lo '
#              'recomendaría este hostal a cualquiera que sé que visitas la '
#              'ciudad ...']}
# 2021-04-01 22:47:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or385-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_40'],
#  'fecha': [' julio de 2013'],
#  'nombre': ['genreina'],
#  'opinion': ['Este hostal está situado en una gran ubicación, todo el mundo es '
#              'muy agradable y servicial, la comida es genial, la vista es '
#              'fantástica, está limpio, es cómodo, y es segura. Si vas, '
#              'sabiendo que será más ruidoso de la noche (estábamos normalmente '
#              'despertaron en hasta las 4 de la mañana), que quizás esté bien. '
#              'Si no hubiera sabido de antemano por leer los comentarios de '
#              'otros, habría sido irritados. A pesar del ruido, tuvimos una '
#              'estancia fantástica y me alojaría aquí de nuevo!']}
# 2021-04-01 22:47:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or385-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_50'],
#  'fecha': [' marzo de 2013'],
#  'nombre': ['Amanda M'],
#  'opinion': ['Realmente disfruté de mi tiempo en Mundo joven. No puedo decir '
#              'nada malo de este hostal, todo el personal era muy amable, había '
#              'una gran seguridad, nunca me sentí no atendidos. El hostal '
#              'ofrece actividades durante el día y por la noche, y eran gratis. '
#              'Desde tours al mercado, a hacer guacamoli. En resumen el hostal '
#              'en unas pocas palabras lo que sería una gran ubicación, buena '
#              'gente, buen ambiente = gran hostal.']}
# 2021-04-01 22:47:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or385-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_50'],
# ...
# 2021-04-01 22:50:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tripadvisor.com.mx/RegistrationController?flow=sign_up_and_save&returnTo=%2FHotel_Review-g150800-d308512-Reviews-or195-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html&fullscreen=true&flowOrigin=login&hideNavigation=true> (referer: https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or195-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html)
# 2021-04-01 22:50:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or205-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html> (referer: https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or195-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html)
# 2021-04-01 22:50:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or205-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_20'],
#  'fecha': [' septiembre de 2013'],
#  'nombre': ['megajelen'],
#  'opinion': ['Nos hemos alojado tres noches en dicho hostel, en una habitación '
#              'de matrimonio. No teníamos espacio para poner la maleta en el '
#              'suelo. Los dos casi no entrábamos de pie en la habitación. La '
#              'habitación da a un patio central del edificio, donde se '
#              'encuentra el bar, la recepción y una televisión puesta todo el '
#              'día con vídeos musicales (tipo MTV). El ruido en la habitación '
#              'es constante hasta las 22 horas. El baño pésimo: una ducha '
#              'mínima con un chorro bestial a presión q hacía daño en el '
#              'cuerpo!!! Eso sí, la estancia incluye desayuno, y el hostel se '
#              'encuentra en pleno zócalo. También decir q tiene una bonita '
#              'terraza y está cerca del metro. Nada más.']}
# 2021-04-01 22:50:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or205-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_40'],
#  'fecha': [' febrero de 2013'],
#  'nombre': ['SteffyO'],
#  'opinion': ['Nos hospedamos en Febrero del 2013, las habitaciones son limpias '
#              'y del tamaño justo cada una con personalidad y vinilos '
#              'decorativos ingeniosos,  de entrada te ofrecen gratis un city '
#              'tour (a pie) y además tiene su propia agencia de viajes que te '
#              'ofrece excursiones dentro y fuera de la ciudad, además de una '
#              'tienda con muchas cosas útiles para los mochileros. Toda la '
#              'semana hay actividades por hacer ( talleres para preparar comida '
#              'y artesanías típicas) y el bar de la terraza tiene unos super '
#              'precios en bebidas ( cierran temprano lo cuál es bueno para los '
#              'que necesitamos descansar e iniciar el día temprano). Lo único '
#              'que podrían mejorar serían los desayunos (muy simples para mi '
#              'gusto). Claro que regreso, el ambiente es lo mejor ! ! !']}
# 2021-04-01 22:50:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or205-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_40'],
#  'fecha': [' julio de 2013'],
#  'nombre': ['maximezazou'],
#  'opinion': ['Ese lugar es un hostel pero también ofrece la posibilidad de '
#              'desayunar un buen desayuno mexicano a un precio  economico (49 '
#              'pesos el desayuno con plato fuerte jugo y cafe) en el zocalo. '
#              'Una excelente manera de empezar el día visitando el centro '
#              'historico de la ciudad']}
# 2021-04-01 22:50:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or205-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_50'],
#  'fecha': [' mayo de 2013'],
#  'nombre': ['Joel V'],
#  'opinion': ['Buenas amigos!. ya tras mi retorno a Argentina quería compartir '
#              'la experiencia de alojarme en Mundo Joven Catedral.  No esta de '
#              'mas decirles que México es asombroso, fue el primer destino en '
#              'el exterior que realizo y sin duda que quería alojarme en '
#              'hoteles cómodos y con buena ubicación. este Hostel es sin duda '
#              'el mejor ubicado detrás de la Catedral metropolitana, a unos '
#              'pasos de la parada de micro que los llevara a recorrer la ciudad '
#              'en sus dos salidas diurnas (de día) y nocturna y lógicamente '
#              'pleno centro. El hotel fue verdaderamente cómodo, el desayuno '
#              'era rico y variado, agua caliente y fría en las habitaciones, tv '
#              'y aire acondicionado, camas muy cómodas y la ventana de mi '
#              'habitación daba a las otras ventanas como todas en el hotel, '
#              'pero así mismo no se escuchara ruidos ni',
#              '…']}
# 2021-04-01 22:50:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or205-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_40'],
#  'fecha': [' abril de 2013'],
#  'nombre': ['Ramiro Backpacker'],
#  'opinion': ['Lo mejor de este hostel es la ubicación, justo detrás de la '
#              'Catedral en pleno Zócalo. Las habitaciones son buenas, con '
#              'ascensor, casilleros bien grandes!! lo único a mejorar es el '
#              'desayuno que es demasiado pobre... muy pobre!!!']}
# 2021-04-01 22:50:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or200-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html> (referer: https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or195-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html)
# 2021-04-01 22:50:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or200-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_40'],
#  'fecha': [' abril de 2014'],
#  'nombre': ['Melisa P'],
#  'opinion': ['Estuve alojada la primer semana de Abril durante 5 noches , La '
#              'atencion del personal es muy amable y seimpre dispuestos a '
#              'ayudar . El desayuno es muy abundante  , mucha variedad y '
#              'reponen continuamente.  Tenia miedo de dejar mi equipaje por '
#              'unos dias pero el Gerente Jaime me genero  mucha confianza asi '
#              'que todo salio barbaro ! Hay una persona de seguridad '
#              'continuamente , eso esta bueno porque parte de la entrada es un '
#              'bar ,asi que entra  gente continuamente. Las habitaciones que '
#              'dan a la calle son las mas ruidosas  , estan frente al zocalo y '
#              'hay ruido constantemente. El bar es excelente ,una vista hermosa '
#              'de dia y de noche , hermoso lugar para desayunar y pasar un buen '
#              'momento.  Si llegas antes del check in (14hs ), hay una '
#              'habitacion en la cual se puede descansar placidamente',
#              '…']}
# 2021-04-01 22:50:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or200-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_40'],
#  'fecha': [' febrero de 2014'],
#  'nombre': ['KARINA R'],
#  'opinion': ['El mejor hostel en el cual me hospedé durante los 2 meses en los '
#              'que recorrí México. Fue también el más caro, 200 $ mexicanos por '
#              'noche, pero los vale absolutamente. La habitación en la que me '
#              'quedé fue una femenina para 6 mujeres. Muy cómoda, amplia, '
#              'limpia, con agua caliente las 24 hrs, lámparas y enchufes '
#              'individuales y buena ventilación. La ubicación es muy buena '
#              'también, así como la seguridad del hostel, su personal y que '
#              'cuente con un elevador. Los espacios en común como el salón de '
#              'estar, la sala de computadoras, la sala de T.V. y, en '
#              'particular, la terraza son agradables y también cómodos y '
#              'amplios.  En mi opinión, lo mejor del Hostel Catedral es su '
#              'desayuno tan variado y abundante, y nada como desayunar en la '
#              'terraza, bajo el sol, con la vista del Zócalo. Otras cosas a',
#              '…']}
# 2021-04-01 22:50:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or200-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_50'],
#  'fecha': [' marzo de 2014'],
#  'nombre': ['Sayra Joanna S'],
#  'opinion': ['Estuve el fin de semana pasado hospedada aquí con un grupo de '
#              'amigas y la verdad nos gustó mucho lo que nos ofrecía el lugar, '
#              'la habitación era pequeña pero no fue inconveniente ya que solo '
#              'estuvimos ahí para dormir pues todo el día la pasamos de tour. '
#              'Contamos con baño privado y agua caliente, el precio muy bueno! '
#              'El desayuno estuvo bien, chilaquiles, huevo y frijoles justo lo '
#              'necesario para iniciar el día. Nos encanto y la verdad pensamos '
#              'ir de nuevo. Además que esta a espaldas de la catedral y justo '
#              'enfrente de la salida del Turibus, el personal nos trato muy '
#              'bien nos consiguieron un taxi seguro y a un buen precio.']}
# 2021-04-01 22:50:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or200-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_30'],
#  'fecha': [' octubre de 2013'],
#  'nombre': ['Cecita_d'],
#  'opinion': ['El hostel es bastante gradable, las habitaciones estan limpias y '
#              'son esteticamente lindas estuvimos en una habitacion privada, '
#              'dos camas, lavatorio, baño y ducha. La habitcion en si es '
#              'extremadamente pequeña por lo cual resulta dificil moverse (y '
#              'mas con las maletas).  Si lo ejien consideren algunos detalles: '
#              'las habitciones dan a patios internos cubiertos y sus ventanas '
#              'se cierran con postigos  y nada mas, por lo cual el sonido los '
#              'atraviesa con facilidad. Tengan en cuenta que a esos mismos '
#              'patios dan la recepcion y el salon de estar y desayunador con '
#              'TV. Ademas, no hay ventilacion que recambie el aire. Tampoco hay '
#              'aire acondicionado o ventilador. Asique si hace calor, es '
#              'dificil dormir.']}
# 2021-04-01 22:50:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or200-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_50'],
#  'fecha': [' octubre de 2013'],
#  'nombre': ['anitamaria8'],
#  'opinion': ['Mi novio y yo no estuvimos hospedados en el hostel pero en '
#              'nuestra visita a la catedral metropolitana del df entramos a '
#              'comer al restaurante y no exagero cuando digo que fue una de las '
#              'mejores comida que tuvimos en nuestra estancia en Mexico (15 '
#              'dias) platos excelentes y saludables, muy poca grasa y con el '
#              'sabor mexicano delicioso. El mesero que nos atendio '
#              'excelentemente nos recomendo probar las crepas de cajeta que no '
#              'sabiamos que era y fue toda una delicia. Un lugar en el que '
#              'deben comer si tienen la oportunidad de estar cerca al Zocalo. '
#              'Felicidades']}
# 2021-04-01 22:50:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tripadvisor.com.mx/RegistrationController?flow=sign_up_and_save&returnTo=%2FHotel_Review-g150800-d308512-Reviews-or190-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html&fullscreen=true&flowOrigin=login&hideNavigation=true> (referer: https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or190-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html)
# 2021-04-01 22:50:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tripadvisor.com.mx/RegistrationController?flow=sign_up_and_save&returnTo=%2FHotel_Review-g150800-d308512-Reviews-or210-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html&fullscreen=true&flowOrigin=login&hideNavigation=true> (referer: https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or210-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html)
# 2021-04-01 22:50:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tripadvisor.com.mx/RegistrationController?flow=sign_up_and_save&returnTo=%2FHotel_Review-g150800-d308512-Reviews-or215-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html&fullscreen=true&flowOrigin=login&hideNavigation=true> (referer: https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or215-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html)
# 2021-04-01 22:50:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tripadvisor.com.mx/RegistrationController?flow=sign_up_and_save&returnTo=%2FHotel_Review-g150800-d308512-Reviews-or205-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html&fullscreen=true&flowOrigin=login&hideNavigation=true> (referer: https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or205-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html)
# 2021-04-01 22:50:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tripadvisor.com.mx/RegistrationController?flow=sign_up_and_save&returnTo=%2FHotel_Review-g150800-d308512-Reviews-or200-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html&fullscreen=true&flowOrigin=login&hideNavigation=true> (referer: https://www.tripadvisor.com.mx/Hotel_Review-g150800-d308512-Reviews-or200-Hostel_Mundo_Joven_Catedral-Mexico_City_Central_Mexico_and_Gulf_Coast.html)
# 2021-04-01 22:50:16 [scrapy.core.engine] INFO: Closing spider (finished)
# 2021-04-01 22:50:16 [scrapy.extensions.feedexport] INFO: Stored csv feed (404 items) in: HostelMundoJoven_Trip.csv
# 2021-04-01 22:50:16 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 642239,
#  'downloader/request_count': 166,
#  'downloader/request_method_count/GET': 166,
#  'downloader/response_bytes': 29856853,
#  'downloader/response_count': 166,
#  'downloader/response_status_count/200': 163,
#  'downloader/response_status_count/503': 3,
#  'dupefilter/filtered': 492,
#  'elapsed_time_seconds': 207.24417,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2021, 4, 2, 4, 50, 16, 933618),
#  'item_scraped_count': 404,
#  'log_count/DEBUG': 571,
#  'log_count/INFO': 14,
#  'log_count/WARNING': 1,
#  'request_depth_max': 20,
#  'response_received_count': 163,
#  'retry/count': 3,
#  'retry/reason_count/503 Service Unavailable': 3,
#  'scheduler/dequeued': 166,
#  'scheduler/dequeued/memory': 166,
#  'scheduler/enqueued': 166,
#  'scheduler/enqueued/memory': 166,
#  'start_time': datetime.datetime(2021, 4, 2, 4, 46, 49, 689448)}
# 2021-04-01 22:50:16 [scrapy.core.engine] INFO: Spider closed (finished)
