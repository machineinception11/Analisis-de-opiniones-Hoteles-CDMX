# %% [markdown]
# # Extracción de Opiniones Hotel 4.	HostelMundoJoven ($389)

# %%
# Importamos librerias
from time import sleep
import pandas as pd
import random
from scrapy.item import Item
from scrapy.item import Field
from scrapy.spiders import CrawlSpider, Rule
from scrapy.loader import ItemLoader
from scrapy.linkextractors import LinkExtractor
from scrapy.selector import Selector
from scrapy.crawler import CrawlerProcess

# %%
class Opiniones(Item):
    nombre = Field()
    opinion = Field()
    calificacion = Field()
    fecha = Field()
    
class Hotel(CrawlSpider):
    # Definimos el nombre del spider
    name = "MumediDesignHotel"
    
    # Definimos la seguridad para no sér detectados
    custom_settings = ({
        "USER_AGENT": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.77 Safari/537.36"
    })
    
    # Tiempo de descarga
    download_delay = 1
    
    # ¿De dónde extraerémos los datos?
    start_urls = ["https://www.tripadvisor.com.mx/Hotel_Review-g150800-d17546680-Reviews-Design_Hotel_Mumedi-Mexico_City_Central_Mexico_and_Gulf_Coast.html"]
    
    # ¿Qué páginas están permitidas?
    allowed_domain = ["tripadvisor.com.mx"]
    
    # Definimos las reglas
    # Scraping horizontal
    rules = (
        Rule(
            LinkExtractor(
                allow = r'-or\d+'
            ), follow = True, callback = 'parse_opiniones'
        ),
    )
    
    # Definimos la función para el parseador
    def parse_opiniones(self, response):
        sel = Selector(response)
        # opiniones = sel.xpath('//div[@data-test-target="reviews-tab"]/div[@data-test-target = HR_CC_CARD]')
        opiniones = sel.xpath('//div[@id = "taplc_resp_hr_ad_wrapper_lower_block_0"]/div/div/div/div/div/div[3]/div[@data-test-target="HR_CC_CARD"]')
        
        for opinion in opiniones:
            item = ItemLoader(Opiniones(), opinion)
            item.add_xpath('nombre', './/a[@class = "ui_header_link _1r_My98y"]/text()')
            item.add_xpath('opinion', './/q[@class = "IRsGHoPm"]/span/text()') 
            item.add_xpath('calificacion', './/div[@data-test-target = "review-rating"]/span[contains(@class, "ui_bubble_rating")]/@class')
            item.add_xpath('fecha', './/span[@class = "_34Xs-BQm"]/text()') 
            
            yield item.load_item()

# %%
process = CrawlerProcess({
    "FEED_FORMAT": "csv",
    "FEED_URI": "HostelMundoJoven_Trip.csv"
})

process.crawl(Hotel)
process.start()
# Out:
# 2021-04-01 22:44:41 [scrapy.utils.log] INFO: Scrapy 2.4.1 started (bot: scrapybot)
# 2021-04-01 22:44:41 [scrapy.utils.log] INFO: Versions: lxml 4.6.1.0, libxml2 2.9.10, cssselect 1.1.0, parsel 1.5.2, w3lib 1.21.0, Twisted 21.2.0, Python 3.7.7 (default, May  6 2020, 11:45:54) [MSC v.1916 64 bit (AMD64)], pyOpenSSL 19.1.0 (OpenSSL 1.1.1k  25 Mar 2021), cryptography 3.2.1, Platform Windows-10-10.0.19041-SP0
# 2021-04-01 22:44:41 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2021-04-01 22:44:41 [scrapy.crawler] INFO: Overridden settings:
# {'USER_AGENT': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 '
#                '(KHTML, like Gecko) Chrome/70.0.3538.77 Safari/537.36'}
# 2021-04-01 22:44:41 [scrapy.extensions.telnet] INFO: Telnet Password: 5de7ff68980e2e33
# 2021-04-01 22:44:41 [py.warnings] WARNING: D:\Anaconda\lib\site-packages\scrapy\extensions\feedexport.py:247: ScrapyDeprecationWarning: The `FEED_URI` and `FEED_FORMAT` settings have been deprecated in favor of the `FEEDS` setting. Please see the `FEEDS` setting docs for more details
#   exporter = cls(crawler)
#
# 2021-04-01 22:44:41 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2021-04-01 22:44:41 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2021-04-01 22:44:41 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2021-04-01 22:44:41 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2021-04-01 22:44:41 [scrapy.core.engine] INFO: Spider opened
# 2021-04-01 22:44:41 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2021-04-01 22:44:41 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2021-04-01 22:44:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tripadvisor.com.mx/Hotel_Review-g150800-d17546680-Reviews-Design_Hotel_Mumedi-Mexico_City_Central_Mexico_and_Gulf_Coast.html> (referer: None)
# 2021-04-01 22:44:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tripadvisor.com.mx/Hotel_Review-g150800-d17546680-Reviews-or5-Design_Hotel_Mumedi-Mexico_City_Central_Mexico_and_Gulf_Coast.html> (referer: https://www.tripadvisor.com.mx/Hotel_Review-g150800-d17546680-Reviews-Design_Hotel_Mumedi-Mexico_City_Central_Mexico_and_Gulf_Coast.html)
# 2021-04-01 22:44:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d17546680-Reviews-or5-Design_Hotel_Mumedi-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_50'],
#  'fecha': [' septiembre de 2019'],
#  'nombre': ['Sightseer49919387991'],
#  'opinion': ['Cada habitación es única y muy particular, con todas las '
#              'comodidades y detalles excepcionales. Uno se siente que se '
#              'encuentra en un viaje donde se unen el pasado y el futuro. Una '
#              'experiencia sensorial increíble.']}
# 2021-04-01 22:44:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d17546680-Reviews-or5-Design_Hotel_Mumedi-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_50'],
#  'fecha': [' agosto de 2019'],
#  'nombre': ['bgemilio'],
#  'opinion': ['Un lugar increíble para hospedarse y pasar el tiempo. Mumedi '
#              'ofrece gran variedad de espacios que disfrutamos: la comida en '
#              'el restaurante ¡de lo mejor!; los cuartos, un agasajo; la '
#              'tienda, no puedes dejar de comprar algo y sobre todo a pocos '
#              'pasos del Zócalo.    El tema de ruido al interior de los cuartos '
#              'está muy bien resuelto, son silenciosos y acogedores (a pesar de '
#              'estar en una de las calles principales del Centro Histórico de '
#              'la CDMX).']}
# 2021-04-01 22:44:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d17546680-Reviews-or5-Design_Hotel_Mumedi-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_50'],
#  'fecha': [' agosto de 2019'],
#  'nombre': ['bmalpicah'],
#  'opinion': ['Pasamos un fin de semana increíble en una habitación '
#              'increíblemente decorada con materiales de la más alta calidad, '
#              'silenciosa y con la mayor comodidad en el corazón de la CDMX! En '
#              'Madero cerca de muchísimas actividades y lugares que visitar. '
#              'Sin duda una opción inmejorable!']}
# 2021-04-01 22:44:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d17546680-Reviews-or5-Design_Hotel_Mumedi-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_50'],
#  'fecha': [' octubre de 2020'],
#  'nombre': ['Hector E'],
#  'opinion': ['Nunca pensé que iba a encontrar un lugar como este en el corazón '
#              'de la Ciudad de México, tranquilo y súper moderno. El lugar es '
#              'realmente un hotel de diseño y las habitaciones te hacen sentir '
#              'como si estuvieras en una revista con muchos gadgets y '
#              'detalles.  Nos cuidaron y nos hicieron sentir como en nuestra '
#              'propia casa, nos mimaron todas las mañanas con un delicioso '
#              'desayuno y el personal totalmente bilingüe brindó mucha '
#              'información sobre las cosas que hacer en la ciudad. Teníamos '
#              'miedo de ir a un hotel por la pandemia pero nos sentimos muy '
#              'seguros por todas las medidas de seguridad que toman y como hay '
#              'pocas habitaciones, no te sientes cerca de otros huéspedes.  Los '
#              'refrescos estaban en nuestra habitación y nos sorprendió mucho '
#              'que fueran gratuitos.  ¡Definitivamente regresaría',
#              '…']}
# 2021-04-01 22:44:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d17546680-Reviews-or5-Design_Hotel_Mumedi-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_50'],
#  'fecha': [' septiembre de 2020'],
#  'nombre': ['droot881937'],
#  'opinion': ['El lugar es como una galería de arte, es realmente genial. La '
#              'ubicación también está justo en el centro del distrito '
#              'histórico, y la habitación estaba muy limpia y era única de '
#              'otros lugares en los que me he alojado. De seguro regresará.']}
# 2021-04-01 22:44:44 [scrapy.dupefilters] DEBUG: Filtered duplicate request: <GET https://www.tripadvisor.com.mx/Hotel_Review-g150800-d17546680-Reviews-or5-Design_Hotel_Mumedi-Mexico_City_Central_Mexico_and_Gulf_Coast.html> - no more duplicates will be shown (see DUPEFILTER_DEBUG to show all duplicates)
# 2021-04-01 22:44:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tripadvisor.com.mx/Hotel_Review-g150800-d17546680-Reviews-or15-Design_Hotel_Mumedi-Mexico_City_Central_Mexico_and_Gulf_Coast.html> (referer: https://www.tripadvisor.com.mx/Hotel_Review-g150800-d17546680-Reviews-Design_Hotel_Mumedi-Mexico_City_Central_Mexico_and_Gulf_Coast.html)
# 2021-04-01 22:44:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d17546680-Reviews-or15-Design_Hotel_Mumedi-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_50'],
#  'fecha': [' julio de 2019'],
#  'nombre': ['AGC'],
#  'opinion': ['El Design Hotel Mumedi está ubicado en el corazón de la Ciudad '
#              'de México en un edificio que alguna vez fue parte del palacio de '
#              'Axayacatl, el padre de Moctezuma y luego parte de la casa de '
#              'Martin Cortes, el hijo de Hernán Cortés. Se encuentra a pocos '
#              'pasos del Palacio Nacional, la Catedral y el Templo Mayor y a '
#              'pocas cuadras del hermoso Palacio de las Artes, el Museo '
#              'Nacional de Arte y el extraordinario Edificio de Correos.  Es un '
#              'edificio bellamente restaurado que combina 6 siglos de historia. '
#              'Solo hay 6 habitaciones, cada una completamente diferente de la '
#              'otra, cada una decorada con un gusto exquisito, las imágenes más '
#              'sorprendentes, las camas más cómodas vestidas con suntuosas '
#              'sábanas y accesorios con la tecnología más avanzada. No se '
#              'reparó en gastos para crear la',
#              '…']}
# 2021-04-01 22:44:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tripadvisor.com.mx/Hotel_Review-g150800-d17546680-Reviews-or10-Design_Hotel_Mumedi-Mexico_City_Central_Mexico_and_Gulf_Coast.html> (referer: https://www.tripadvisor.com.mx/Hotel_Review-g150800-d17546680-Reviews-Design_Hotel_Mumedi-Mexico_City_Central_Mexico_and_Gulf_Coast.html)
# 2021-04-01 22:44:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d17546680-Reviews-or10-Design_Hotel_Mumedi-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_20'],
#  'fecha': [' agosto de 2020'],
#  'nombre': ['Jen'],
#  'opinion': ['Mi esposo y yo reservamos este lugar por dos noches y el hotel '
#              'confirmó que estaba bien registrarse a la 1 pm; sin embargo, '
#              'cuando llegamos allí, las puertas estaban cerradas. Llamé al '
#              'número de teléfono varias veces y no pude comunicarme. Pídale a '
#              'los oficiales en la calle que llamen y averigüen por mí si '
#              'estaban abiertos y tampoco pudieron ponerse en contacto con el '
#              'hotel. Entonces 1. 5 horas después, decidimos conseguir una '
#              'habitación en el hotel al otro lado de la calle. Justo cuando '
#              'entramos en nuestra nueva habitación, nos llaman y nos dicen que '
#              'nos están esperando. . . . . . . . .  No obtuvimos un reembolso. '
#              'Dijeron que nadie llamó. . . . bastante perturbador. Dicen que '
#              'las puertas estaban cerradas pero que el hotel del edificio '
#              'sigue abierto. Si espera invitados, debe',
#              '…']}
# 2021-04-01 22:44:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d17546680-Reviews-or10-Design_Hotel_Mumedi-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_50'],
#  'fecha': [' febrero de 2020'],
#  'nombre': ['24tun8'],
#  'opinion': ['Este es un hotel único que se encuentra en el corazón de la '
#              'parte histórica de la Ciudad de México. Nuestra habitación era '
#              'tranquila y muy cómoda. El hotel es nuevo y totalmente '
#              'remodelado de un edificio histórico. Teníamos la habitación '
#              'número 3. El desayuno era delicioso y se sirve en la cafetería '
#              'que está junto a una galería de arte y una tienda. El servicio '
#              'personalizado fue el mejor. Fue muy agradable caminar por la '
#              'cafetería y saludar y sonreír a las personas que trabajaban allí '
#              'cuando entramos y salimos del hotel. Definitivamente un hotel '
#              'boutique cálido y acogedor. Definitivamente regresaremos para '
#              'quedarnos de nuevo. Gracias por todo.']}
# 2021-04-01 22:44:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d17546680-Reviews-or10-Design_Hotel_Mumedi-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_50'],
#  'fecha': [' enero de 2020'],
#  'nombre': ['Gerri Y'],
#  'opinion': ['Pasamos 3 noches excepcionales en este hotel nuevo, moderno y '
#              'hermoso en el Centro Histórico; en Fransisco Madero, una calle '
#              'peatonal en la cuadra que conduce al Zócalo (plaza principal). '
#              'Aunque esta calle está muy concurrida, una vez dentro del hotel, '
#              'es un refugio tranquilo con habitaciones grandes, baños modernos '
#              'y camas excepcionalmente cómodas. El maravilloso personal no '
#              'pudo hacer más por nosotros, fueron amables y nos ayudaron en '
#              'todo lo que pudieron. La propiedad tiene un excelente '
#              'restaurante para el desayuno de cortesía, ¡pero también nos '
#              'dieron café y pasteles para despertar! Tienen una tienda que '
#              'vende diseño contemporáneo y una galería, por lo que, en '
#              'general, es un lugar interesante para quedarse y al mismo tiempo '
#              'mantener el ambiente tranquilo tan importante para',
#              '…']}
# 2021-04-01 22:44:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d17546680-Reviews-or10-Design_Hotel_Mumedi-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_50'],
#  'fecha': [' febrero de 2020'],
#  'nombre': ['Jesica B'],
#  'opinion': ['Mi esposo y yo tuvimos una gran estancia en el hotel Mumedi! '
#              'Definitivamente lo recomendaría a otros, como siempre, viene con '
#              'algunos pros y contras, pero el lugar no tiene parangón.  '
#              'Pros: \xa0- Increíble personal. Una vez que esté allí, puede '
#              "enviarles mensajes a través de la aplicación What's. Servicio a "
#              'la habitación, servicio de despertador, café, consejos sobre '
#              'dónde conseguir un súper, simplemente envíeles un mensaje y '
#              'responderán en un par de minutos. \xa0- Bellamente diseñado. '
#              'Todos los muebles y accesorios encajan perfectamente. Me '
#              'encantaron los pequeños detalles, como la forma en que el champú '
#              'y el jabón estaban incorporados en dispensadores en lugar de '
#              'pequeñas botellas derrochadoras. \xa0- Ubicación. No se puede '
#              'superar la ubicación. Manos abajo. Justo en el centro',
#              '…']}
# 2021-04-01 22:44:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.tripadvisor.com.mx/Hotel_Review-g150800-d17546680-Reviews-or10-Design_Hotel_Mumedi-Mexico_City_Central_Mexico_and_Gulf_Coast.html>
# {'calificacion': ['ui_bubble_rating bubble_40'],
#  'fecha': [' octubre de 2019'],
#  'nombre': ['delkc2002'],
#  'opinion': ['La ubicación es excelente ya que estaba justo al lado de la '
#              'plaza principal de la Ciudad de México y de los principales '
#              'lugares de interés turístico de la Ciudad de México. Hay muchas '
#              'opciones para comer cerca o alrededor del hotel, incluido el '
#              'famoso Al C. Las habitaciones estaban equipadas con ventanas de '
#              'doble acristalamiento, lo cual era importante ya que el hotel '
#              'está en un paseo peatonal que puede estar bastante lleno y '
#              'ruidoso. La cama era cómoda y la adición de un ventilador de '
#              'techo ayudó con la circulación del aire en la habitación. El '
#              'baño era amplio y tenía accesorios caros. La comida en el '
#              'restaurante era buena y moderna, especialmente si quieres otro '
#              'taco.  Ahora a los eventos negativos: \xa01) Será útil informar '
#              'a los huéspedes potenciales que el hotel está ubicado',
#              '…']}
# 2021-04-01 22:44:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tripadvisor.com.mx/RegistrationController?flow=sign_up_and_save&returnTo=%2FHotel_Review-g150800-d17546680-Reviews-or5-Design_Hotel_Mumedi-Mexico_City_Central_Mexico_and_Gulf_Coast.html&fullscreen=true&flowOrigin=login&hideNavigation=true> (referer: https://www.tripadvisor.com.mx/Hotel_Review-g150800-d17546680-Reviews-or5-Design_Hotel_Mumedi-Mexico_City_Central_Mexico_and_Gulf_Coast.html)
# 2021-04-01 22:44:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tripadvisor.com.mx/RegistrationController?flow=sign_up_and_save&returnTo=%2FHotel_Review-g150800-d17546680-Reviews-or15-Design_Hotel_Mumedi-Mexico_City_Central_Mexico_and_Gulf_Coast.html&fullscreen=true&flowOrigin=login&hideNavigation=true> (referer: https://www.tripadvisor.com.mx/Hotel_Review-g150800-d17546680-Reviews-or15-Design_Hotel_Mumedi-Mexico_City_Central_Mexico_and_Gulf_Coast.html)
# 2021-04-01 22:44:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.tripadvisor.com.mx/RegistrationController?flow=sign_up_and_save&returnTo=%2FHotel_Review-g150800-d17546680-Reviews-or10-Design_Hotel_Mumedi-Mexico_City_Central_Mexico_and_Gulf_Coast.html&fullscreen=true&flowOrigin=login&hideNavigation=true> (referer: https://www.tripadvisor.com.mx/Hotel_Review-g150800-d17546680-Reviews-or10-Design_Hotel_Mumedi-Mexico_City_Central_Mexico_and_Gulf_Coast.html)
# 2021-04-01 22:44:50 [scrapy.core.engine] INFO: Closing spider (finished)
# 2021-04-01 22:44:50 [scrapy.extensions.feedexport] INFO: Stored csv feed (11 items) in: HostelMundoJoven_Trip.csv
# 2021-04-01 22:44:50 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 24101,
#  'downloader/request_count': 7,
#  'downloader/request_method_count/GET': 7,
#  'downloader/response_bytes': 1327614,
#  'downloader/response_count': 7,
#  'downloader/response_status_count/200': 7,
#  'dupefilter/filtered': 12,
#  'elapsed_time_seconds': 8.931477,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2021, 4, 2, 4, 44, 50, 691141),
#  'item_scraped_count': 11,
#  'log_count/DEBUG': 19,
#  'log_count/INFO': 11,
#  'log_count/WARNING': 1,
#  'request_depth_max': 2,
#  'response_received_count': 7,
#  'scheduler/dequeued': 7,
#  'scheduler/dequeued/memory': 7,
#  'scheduler/enqueued': 7,
#  'scheduler/enqueued/memory': 7,
#  'start_time': datetime.datetime(2021, 4, 2, 4, 44, 41, 759664)}
# 2021-04-01 22:44:50 [scrapy.core.engine] INFO: Spider closed (finished)
