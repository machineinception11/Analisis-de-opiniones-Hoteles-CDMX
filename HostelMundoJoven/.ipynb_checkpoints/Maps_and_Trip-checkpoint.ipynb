# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import nltk
import string
from wordcloud import WordCloud

# %%
# Cargamos los datos
maps = pd.read_csv("./", encoding = "utf8")
trip = pd.read_csv("./", encoding = "utf8")

# %%
maps.head(1)
# Out:
#    Unnamed: 0                                        Descripción   Año  Mes  \
# 0           0  Hermoso lugar transporta tiempo Atención formi...  2021    3
#
#    retroalimentacion
# 0                  1

# %%
trip.head(1)
# Out:
#    Unnamed: 0                                            opinion  mes   año  \
# 0           0  tercera vez razón volveremos todas comodidades...    3  2011
#
#    retroalimentacion
# 0                  1

# %%
maps.dropna(inplace = True)
trip.dropna(inplace = True)

# %%
# Reseteamos index
trip.reset_index(inplace = True)
maps.reset_index(inplace = True)

# %%
# Eliminamos columnas
trip.drop(["index", "Unnamed: 0"], axis = 1, inplace = True)
maps.drop(["index", "Unnamed: 0"], axis = 1, inplace = True)

# %%
# Renombramos las opiniones para que queden igual
columnas = ["opinion", "año", "mes", "retroalimentacion"]
maps.columns = columnas

# %%
maps.head(1)
# Out:
#                                              opinion   año  mes  \
# 0  Hermoso lugar transporta tiempo Atención formi...  2021    3
#
#    retroalimentacion
# 0                  1

# %%
trip.head(1)
# Out:
#                                              opinion  mes   año  \
# 0  tercera vez razón volveremos todas comodidades...    3  2011
#
#    retroalimentacion
# 0                  1

# %%
# Ahora unimos lod dos datasets
BW_df = pd.concat([trip, maps], axis = 0)

# %%
BW_df.reset_index(inplace = True)
BW_df.drop("index", axis = 1, inplace = True)

# %%
# Vemos que no haya datos vacios
BW_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1135 entries, 0 to 1134
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   opinion            1135 non-null   object
#  1   mes                1135 non-null   int64
#  2   año                1135 non-null   int64
#  3   retroalimentacion  1135 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 35.6+ KB

# %%
BW_df
# Out:
#                                                 opinion  mes   año  \
# 0     tercera vez razón volveremos todas comodidades...    3  2011
# 1     Bueno esperaba dieron pareció sentimiento gene...    1  2009
# 2     ubicación puede ser mejor ¡También cosita ruid...   11  2008
# 3     segunda estancia Majestic primera vez dieron h...    6  2008
# 4     Actualmente alojo aquí día necesita renovación...    1  2008
# ...                                                 ...  ...   ...
# 1130                            HERMOSA Original LINDOS    4  2017
# 1131                       Exquisito Original Exquisite    4  2015
# 1132                         Ta culey Original Ta culey    4  2015
# 1133  Tomé copa restaurante azotea café sabía agua i...    4  2014
# 1134  Der Service ist sehr antiquiert obwohl auf der...    4  2011
#
#       retroalimentacion
# 0                     1
# 1                     0
# 2                     1
# 3                     0
# 4                     1
# ...                 ...
# 1130                  1
# 1131                  1
# 1132                  0
# 1133                  0
# 1134                  1
#
# [1135 rows x 4 columns]

# %%
# Usando los 2 datasets
sns.set_style('whitegrid')

# %%
# Viendo de otra manera las críticas del hotel
plt.figure(figsize = (5,5))
sns.countplot(x = "retroalimentacion", data = BW_df, palette = "Set2")
plt.title("Retroalimentación positiva vs negativa")
plt.xlabel("Retroalimentación")
plt.show()

# %%
# ¿De que año son las criticas?
plt.figure(figsize = (12,7))
sns.countplot(x = "año", data =  BW_df)
plt.title("Año de calificación")
plt.xlabel("Año")
# Out:
# Text(0.5, 0, 'Año')

# %%
# ¿Hay una relevancia entre la retroalimentación y el año?
plt.figure(figsize = (12,7))
sns.countplot(x = "año", data =  BW_df, hue = "retroalimentacion")
plt.title("Año de calificación")
plt.xlabel("Año")
plt.show()

# %%
# Cantidad de opiniones realizadas durante el 2020
plt.figure(figsize = (12,7))
sns.countplot(x = "mes", data =  BW_df[BW_df["año"] == 2020], hue = "retroalimentacion")
plt.title("Año de la pandemia")
plt.xlabel("Año")
plt.show()

# %%
# Cantidad de opiniones realizadas durante el 2020
plt.figure(figsize = (12,7))
sns.countplot(x = "mes", data =  BW_df, hue = "retroalimentacion")
plt.title("Año de la pandemia")
plt.xlabel("Año")
plt.show()

# %%
# Boxplot para ver en donde se acumulan las opiniones de los usuarios
sns.boxplot(x = "año", data = BW_df)
plt.title("Acumulación de las opiniones con respecto al año")
# Out:
# Text(0.5, 1.0, 'Acumulación de las opiniones con respecto al año')

# %%
BW_df[785:790]
# Out:
#                   opinion  mes   año  retroalimentacion
# 785   Muchas deficiencias    4  2020                  0
# 786      Encuentro pasado    4  2020                  1
# 787                Bonito    4  2020                  0
# 788                  Buen    4  2020                  1
# 789  Excelente restaurant    4  2019                  1

# %%
# Sepraemos las opiniones buenas de las malas
buenas = ""
malas = ""
for i, cal in enumerate(BW_df["retroalimentacion"]):
    if cal == 1:
        buenas += BW_df["opinion"][i]
    else:
        malas += BW_df["opinion"][i]

# %%
wordcloud1 = WordCloud().generate(buenas)
wordcloud2 = WordCloud().generate(malas)

# %%
# Las palabras más usadas en la retroalimentación positiva
plt.figure(figsize = (12,12))
plt.imshow(wordcloud1)
plt.title("Reseñas con retroalimentación positiva")
plt.grid(False)
plt.axis(False)
plt.show()

# %%
# Las palabras más usadas en la retroalimentación negativa
plt.figure(figsize = (12,12))
plt.imshow(wordcloud2)
plt.title("Reseñas con retroalimentación negativa")
plt.grid(False)
plt.axis(False)
plt.show()

# %%
# Guardamos la información pre procesada
BW_df.to_csv("BW_preprocesado_todos_los_datos.csv")

# %%
# Cargamos los datos
maps_bruto = pd.read_csv("./Maps_opiniones.csv", encoding = "utf8")
trip_bruto = pd.read_csv("./Trip_opiniones.csv", encoding = "utf8")

# %%
maps_bruto.head(1)
# Out:
#                 Usuario                      Fecha  \
# 0  Andrea Guerrero Rojo  2 semanas atrás en Google
#
#                                          Descripción  Calificacion
# 0  Hermoso lugar, que te transporta a otro tiempo...             5

# %%
trip_bruto.head(1)
# Out:
#    calificacion           fecha    nombre  \
# 0             4   marzo de 2011  yoliee48
#
#                                              opinion
# 0  Este hotel será mi tercera vez en este hotel. ...

# %%
maps_bruto.dropna(inplace = True)
trip_bruto.dropna(inplace = True)

# %%
maps_bruto.drop("Unnamed: 0", axis = 1, inplace = True)

# %%
# Calificaciones
calificaciones_maps = []
calificaciones_trip = []

for cali_maps in maps_bruto["Calificacion"]:
    calificaciones_maps.append(int(cali_maps[0]))


for cali_trip in trip_bruto["calificacion"]:
    calificaciones_trip.append(int(cali_trip[-2]))

# %%
maps_bruto["Calificacion"] = calificaciones_maps
trip_bruto["calificacion"] = calificaciones_trip

# %%
caliifcaciones_unidas = calificaciones_maps + calificaciones_trip
calificaciones = []

uno = []
dos = []
tres = []
cuatro = []
cinco = []

for calificacion in caliifcaciones_unidas:
    if calificacion <= 5:
        calificaciones.append(calificacion)
    else:
        calificaciones.append(5)
        
    if calificacion == 5:
        cinco.append(calificacion)
    elif calificacion == 4:
        cuatro.append(calificacion)
    elif calificacion == 3:
        tres.append(calificacion)
    elif calificacion == 2:
        dos.append(calificacion)
    elif calificacion == 1:
        uno.append(calificacion)

# %%
plt.figure(figsize = (5,5))
sns.histplot(calificaciones)
plt.title("Histograma de calificaciones")
# Out:
# Text(0.5, 1.0, 'Histograma de calificaciones')

# %%
# Pocerntaje de calificación
TOTAL_OPINIONES = len(calificaciones)
print("Porcentaje con calificación {} es {:.2f}%".format(1, (len(uno)/TOTAL_OPINIONES)*100))   
print("Porcentaje con calificación {} es {:.2f}%".format(2, (len(dos)/TOTAL_OPINIONES)*100))   
print("Porcentaje con calificación {} es {:.2f}%".format(3, (len(tres)/TOTAL_OPINIONES)*100))   
print("Porcentaje con calificación {} es {:.2f}%".format(4, (len(cuatro)/TOTAL_OPINIONES)*100))   
print("Porcentaje con calificación {} es {:.2f}%".format(5, (len(cinco)/TOTAL_OPINIONES)*100))   
    
print("\nEs bueno 65.34%")    
print("Debe mejorar 34.66%")
# Out:
# Porcentaje con calificación 1 es 9.61%
# Porcentaje con calificación 2 es 7.14%
# Porcentaje con calificación 3 es 16.93%
# Porcentaje con calificación 4 es 27.60%
# Porcentaje con calificación 5 es 37.74%
#
# Es bueno 65.34%
# Debe mejorar 34.66%

# %%
# Opiniones buenas

# %%
maps_bruto[maps_bruto["Calificacion"] >= 4]["Descripción"]
# Out:
# 0      Hermoso lugar, que te transporta a otro tiempo...
# 1      Es un Hotel excelente donde su personal siempr...
# 5      Una vista muy grata, buen sabor de los aliment...
# 6                                     Muy buena atencion
# 8      No me gustó el platillo de nombre "molcajete",...
#                              ...
# 773          (Traducción de Google) C:\n\n(Original)\nC:
# 774    (Traducción de Google) Tan increíble\n\n(Origi...
# 775    (Traducción de Google) HERMOSA\n\n(Original)\n...
# 776    (Traducción de Google) Exquisito\n\n(Original)...
# 779    Der Service ist sehr antiquiert, obwohl auf de...
# Name: Descripción, Length: 563, dtype: object

# %%
trip_bruto[trip_bruto["calificacion"] >= 4]["opinion"]
# Out:
# 0      Este hotel será mi tercera vez en este hotel. ...
# 2        La ubicación de este hotel no puede ser mejo...
# 4        Actualmente me alojo aquí día 4 de 6 en el h...
# 9      El único problema es el ruido de la calle o la...
# 13     Nos alojamos en este hotel histórico de 2011 N...
#                              ...
# 346    Buen hotel, habitaciones limpias con camas cóm...
# 347    Hotel situado en la Plaza del Zócalo, la ubica...
# 351    Buen servicio y excelente vista y ubicacion en...
# 354    Es un edificio de varios siglos, agradable los...
# 355    excelente servicio del personal, pero a las ha...
# Name: opinion, Length: 189, dtype: object

# %%
maps_bruto["Descripción"][317]
# Out:
# 'Un lugar agradable con una vista maravillosa al Centro Histórico de la CDMX y el restaurante en la terraza con vista al Zócalo Capitalismo, un lugar mágico'

# %%
maps_bruto["Calificacion"][300:320]
# Out:
# 300    3
# 301    4
# 302    4
# 303    5
# 304    5
# 305    5
# 306    1
# 307    5
# 308    5
# 309    3
# 310    5
# 311    4
# 312    4
# 313    5
# 314    4
# 315    4
# 316    5
# 317    5
# 318    3
# 319    4
# Name: Calificacion, dtype: int64

# %%
# Opiniones malas

# %%
maps_bruto[maps_bruto["Calificacion"] < 4]["Descripción"]
# Out:
# 2      Muy atentos y educados. Me decepcionó la comid...
# 3      Tal vez la excelente ubicación hace que dejen ...
# 4      Vista fantástica del Zócalo y de la Catedral. ...
# 7      El personal es muy atento y amable, pero no ti...
# 12     Visitamos la terraza y la vista es increíble, ...
#                              ...
# 753          (Traducción de Google) OK\n\n(Original)\nOk
# 755               oh it is the best hotel in Mexico City
# 756    (Traducción de Google) La ubicación es excelen...
# 777    (Traducción de Google) Ta culey\n\n(Original)\...
# 778    (Traducción de Google) Tomé una copa en el res...
# Name: Descripción, Length: 217, dtype: object

# %%
trip_bruto[trip_bruto["calificacion"] < 4]["opinion"]
# Out:
# 1        Bueno, me esperaba mucho más de lo que me di...
# 3      Esta era nuestra segunda estancia en el Majest...
# 5      El lugar necesita renovación, fi-la conexión f...
# 6      Nos alojamos aquí en una tarifa muy reducida, ...
# 7      Mi esposa y yo nos hemos alojado en el hotel M...
#                              ...
# 349    Terraza con vistas increíbles a la catedral pe...
# 350    La ubicación del hotel es bastante buena, pues...
# 352    Es céntrico si, su rótulo es pequeño y no visi...
# 353    Nadaaa que ver este hotel,no hay estacionamien...
# 356    El hotel tiene una excelente ubicación y ni ha...
# Name: opinion, Length: 165, dtype: object

# %%
maps_bruto["Descripción"][12]
# Out:
# 'Visitamos la terraza y la vista es increíble, buen protocolo ante la contingencia. La comida me dejó mucho que desear, poca disponibilidad de los platillos y mala relación calidad-precio. Sabor nada fuera de lo común.'
